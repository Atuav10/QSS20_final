# %% [markdown]
# ## QSS20 Final Project - Weather-based Passing Statistics in the NFL

# %%
import pandas as pd
import nfl_data_py as nfl
import numpy as np
import matplotlib.pyplot as plt
import graphviz

# %%
pbp = nfl.import_pbp_data(range(2014,2024))
# Out:
# 2014 done.
# 2015 done.
# 2016 done.
# 2017 done.
# 2018 done.
# 2019 done.
# 2020 done.
# 2021 done.
# 2022 done.
# 2023 done.
# Downcasting floats.

# %%
columns_list = list(pbp.columns)
print(columns_list)
# Out:
# ['play_id', 'game_id', 'old_game_id', 'home_team', 'away_team', 'season_type', 'week', 'posteam', 'posteam_type', 'defteam', 'side_of_field', 'yardline_100', 'game_date', 'quarter_seconds_remaining', 'half_seconds_remaining', 'game_seconds_remaining', 'game_half', 'quarter_end', 'drive', 'sp', 'qtr', 'down', 'goal_to_go', 'time', 'yrdln', 'ydstogo', 'ydsnet', 'desc', 'play_type', 'yards_gained', 'shotgun', 'no_huddle', 'qb_dropback', 'qb_kneel', 'qb_spike', 'qb_scramble', 'pass_length', 'pass_location', 'air_yards', 'yards_after_catch', 'run_location', 'run_gap', 'field_goal_result', 'kick_distance', 'extra_point_result', 'two_point_conv_result', 'home_timeouts_remaining', 'away_timeouts_remaining', 'timeout', 'timeout_team', 'td_team', 'td_player_name', 'td_player_id', 'posteam_timeouts_remaining', 'defteam_timeouts_remaining', 'total_home_score', 'total_away_score', 'posteam_score', 'defteam_score', 'score_differential', 'posteam_score_post', 'defteam_score_post', 'score_differential_post', 'no_score_prob', 'opp_fg_prob', 'opp_safety_prob', 'opp_td_prob', 'fg_prob', 'safety_prob', 'td_prob', 'extra_point_prob', 'two_point_conversion_prob', 'ep', 'epa', 'total_home_epa', 'total_away_epa', 'total_home_rush_epa', 'total_away_rush_epa', 'total_home_pass_epa', 'total_away_pass_epa', 'air_epa', 'yac_epa', 'comp_air_epa', 'comp_yac_epa', 'total_home_comp_air_epa', 'total_away_comp_air_epa', 'total_home_comp_yac_epa', 'total_away_comp_yac_epa', 'total_home_raw_air_epa', 'total_away_raw_air_epa', 'total_home_raw_yac_epa', 'total_away_raw_yac_epa', 'wp', 'def_wp', 'home_wp', 'away_wp', 'wpa', 'vegas_wpa', 'vegas_home_wpa', 'home_wp_post', 'away_wp_post', 'vegas_wp', 'vegas_home_wp', 'total_home_rush_wpa', 'total_away_rush_wpa', 'total_home_pass_wpa', 'total_away_pass_wpa', 'air_wpa', 'yac_wpa', 'comp_air_wpa', 'comp_yac_wpa', 'total_home_comp_air_wpa', 'total_away_comp_air_wpa', 'total_home_comp_yac_wpa', 'total_away_comp_yac_wpa', 'total_home_raw_air_wpa', 'total_away_raw_air_wpa', 'total_home_raw_yac_wpa', 'total_away_raw_yac_wpa', 'punt_blocked', 'first_down_rush', 'first_down_pass', 'first_down_penalty', 'third_down_converted', 'third_down_failed', 'fourth_down_converted', 'fourth_down_failed', 'incomplete_pass', 'touchback', 'interception', 'punt_inside_twenty', 'punt_in_endzone', 'punt_out_of_bounds', 'punt_downed', 'punt_fair_catch', 'kickoff_inside_twenty', 'kickoff_in_endzone', 'kickoff_out_of_bounds', 'kickoff_downed', 'kickoff_fair_catch', 'fumble_forced', 'fumble_not_forced', 'fumble_out_of_bounds', 'solo_tackle', 'safety', 'penalty', 'tackled_for_loss', 'fumble_lost', 'own_kickoff_recovery', 'own_kickoff_recovery_td', 'qb_hit', 'rush_attempt', 'pass_attempt', 'sack', 'touchdown', 'pass_touchdown', 'rush_touchdown', 'return_touchdown', 'extra_point_attempt', 'two_point_attempt', 'field_goal_attempt', 'kickoff_attempt', 'punt_attempt', 'fumble', 'complete_pass', 'assist_tackle', 'lateral_reception', 'lateral_rush', 'lateral_return', 'lateral_recovery', 'passer_player_id', 'passer_player_name', 'passing_yards', 'receiver_player_id', 'receiver_player_name', 'receiving_yards', 'rusher_player_id', 'rusher_player_name', 'rushing_yards', 'lateral_receiver_player_id', 'lateral_receiver_player_name', 'lateral_receiving_yards', 'lateral_rusher_player_id', 'lateral_rusher_player_name', 'lateral_rushing_yards', 'lateral_sack_player_id', 'lateral_sack_player_name', 'interception_player_id', 'interception_player_name', 'lateral_interception_player_id', 'lateral_interception_player_name', 'punt_returner_player_id', 'punt_returner_player_name', 'lateral_punt_returner_player_id', 'lateral_punt_returner_player_name', 'kickoff_returner_player_name', 'kickoff_returner_player_id', 'lateral_kickoff_returner_player_id', 'lateral_kickoff_returner_player_name', 'punter_player_id', 'punter_player_name', 'kicker_player_name', 'kicker_player_id', 'own_kickoff_recovery_player_id', 'own_kickoff_recovery_player_name', 'blocked_player_id', 'blocked_playe ...

# %% [markdown]
# ### Section 1 - General

# %% [markdown]
# Goals:
# - Filter pbp dataset to only include pass attempts
# - Group by players and summarize the average epa (expected points added) and total attempts

# %%
pbp = pbp[pbp["pass_attempt"] == 1]

# %%
pbp_grouped = pbp.groupby("passer_player_name").agg(team=('posteam', 'last'), mean_epa=('epa', 'mean'), sum_att=('pass_attempt', 'sum'))
pbp_filtered = pbp_grouped[pbp_grouped["sum_att"] > 500]
pd.set_option('display.max_rows', None)
pbp_filtered = pbp_filtered.sort_values(by="mean_epa", ascending=False)

# %%
pbp_filtered.head(20)
# Out:
#                    team  mean_epa  sum_att
# passer_player_name
# B.Purdy              SF  0.260180    833.0
# P.Mahomes            KC  0.222529   4455.0
# T.Romo              DAL  0.184863    655.0
# T.Brady              TB  0.156850   6715.0
# D.Brees              NO  0.155805   4176.0
# A.Rodgers           NYJ  0.137633   5241.0
# J.Garoppolo          LV  0.135447   2180.0
# J.Love               GB  0.132817    754.0
# P.Rivers            IND  0.126503   4393.0
# D.Prescott          DAL  0.111451   4417.0
# B.Roethlisberger    PIT  0.108336   4707.0
# T.Tagovailoa        MIA  0.105459   1777.0
# C.Stroud            HOU  0.105114    595.0
# J.Allen             BUF  0.095079   3593.0
# J.Burrow            CIN  0.094655   2332.0
# M.Ryan              IND  0.093107   5712.0
# C.Palmer            ARI  0.089797   1814.0
# L.Jackson           BAL  0.085586   2512.0
# A.Luck              IND  0.083115   2396.0
# J.Herbert           LAC  0.082497   2610.0

# %%
plt.figure(figsize=(12, 8))
plt.scatter(pbp_filtered['mean_epa'], pbp_filtered['sum_att'], color='blue', alpha=0.7)

plt.xlabel('Mean EPA')
plt.ylabel('Total Pass Attempts')
plt.title('Mean EPA vs. Total Pass Attempts for Each Player')

for player, row in pbp_filtered.iterrows():
    plt.annotate(player, (row['mean_epa'], row['sum_att']), fontsize=8, ha='right')

plt.show()

# %% [markdown]
# ### Section 2 - Weather

# %%
#This is what the weather column looks like
pbp["weather"].head()
# Out:
# 4     Sunny Temp: 74° F, Humidity: 45%, Wind: NE 3 mph
# 7     Sunny Temp: 74° F, Humidity: 45%, Wind: NE 3 mph
# 8     Sunny Temp: 74° F, Humidity: 45%, Wind: NE 3 mph
# 9     Sunny Temp: 74° F, Humidity: 45%, Wind: NE 3 mph
# 12    Sunny Temp: 74° F, Humidity: 45%, Wind: NE 3 mph
# Name: weather, dtype: object

# %% [markdown]
# # Create a function that extracts the weather

# %%
#Let us see what we are working with first
pbp['first_word_weather'] = pbp['weather'].str.split().str[0]
pbp["first_word_weather"].value_counts()
# Out:
# /var/folders/6q/jmrgx0xj5t7b7l152lzdznmr0000gn/T/ipykernel_78330/2493116823.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   pbp['first_word_weather'] = pbp['weather'].str.split().str[0]
# first_word_weather
# Cloudy           47717
# Sunny            41210
# Partly           22712
# Temp:            20938
# Clear            16710
# Mostly           14828
# Rain              6961
# Controlled        6077
# N/A               6070
# Fair              2601
# Indoors           2226
# Overcast          1555
# Cloudy,           1430
# Light             1395
# Snow               852
# Sunny,             737
# Indoor             651
# Hazy               436
# Clear,             400
# cloudy             305
# Rainy              292
# No                 250
# clear              223
# T:                 223
# Cold               222
# sunny              199
# Scattered          196
# Foggy              170
# 0%                 160
# n/a                159
# Party              147
# SUNNY              145
# partly             138
# Showers            130
# Thunderstorms       99
# Mosly               92
# Mid                 91
# Outdoor             89
# Dry                 87
# Steady              84
# Climate             83
# Zero                79
# sUNNY               78
# Occasional          77
# Flurries            77
# Fog                 77
# overcast            76
# scattered           74
# Raining,            73
# Upper               72
# Sun                 71
# Freezing            70
# Threat              68
# Cloundy             68
# CLOUDY              68
# Warm                66
# Sun/Clouds          66
# Cold,               66
# Drizzle             66
# Cloudly             66
# Raining             65
# Coudy               65
# 30%                 64
# 10%                 64
# Hazey               62
# Temperatures        62
# Breezy              60
# Frigid              48
# Heavy               38
# Name: count, dtype: int64

# %% [markdown]
# As we can see, a lot of synonyms. We could use AI to group them but I will just do it manually. We can also see that many entries do not have proper weather entries

# %%
pbp['is_sunny'] = np.where(pbp['weather'].str.contains('sunny|clear', case=False, na=False), 1, 0)
pbp['is_cloudy'] = np.where(pbp['weather'].str.contains('Cloudy | Cloudly', case=False, na=False), 1, 0)
pbp['is_percipitation'] = np.where(pbp['weather'].str.contains('Rain | Raining, | scattered | Raining | Thunderstorms | Showers | Scattered | Snow | Flurries | Scattered', case=False, na=False), 1, 0)

print(pbp[["is_sunny", "is_cloudy", "is_percipitation"]].mean())
# Out:
# is_sunny            0.336594
# is_cloudy           0.379742
# is_percipitation    0.052960
# dtype: float64

# %%
mean_epa_sunny = pbp.loc[pbp["is_sunny"] == 1, "epa"].mean()
mean_epa_cloudy = pbp.loc[pbp["is_cloudy"] == 1, "epa"].mean()
mean_epa_rainy = pbp.loc[pbp["is_percipitation"] == 1, "epa"].mean()
print(mean_epa_sunny, mean_epa_cloudy, mean_epa_rainy)
# Out:
# 0.030000351 0.022475053 -0.043500226

# %% [markdown]
# We do not have many entries, but we can clearly see the **epa goes down significantly when it is rainy.**

# %%
pbp_sunny = pbp[pbp["is_sunny"] == 1]
pbp_cloudy = pbp[pbp["is_cloudy"] == 1]
pbp_rainy = pbp[pbp["is_percipitation"] == 1]

# %%
pbp_grouped_sunny = pbp_sunny.groupby("passer_player_name").agg(team=('posteam', 'last'), mean_epa_sunny=('epa', 'mean'), sum_att_sunny=('pass_attempt', 'sum'))
pbp_filtered_sunny = pbp_grouped_sunny[pbp_grouped_sunny["sum_att_sunny"] > 100]
pd.set_option('display.max_rows', None)
pbp_filtered_sunny = pbp_filtered_sunny.sort_values(by="mean_epa_sunny", ascending=False)
print(f"EPA in optimal weather: {pbp_filtered_sunny}")
# Out:
# EPA in optimal weather:                     team  mean_epa_sunny  sum_att_sunny
# passer_player_name
# B.Purdy               SF        0.368618          282.0
# P.Mahomes             KC        0.341232          962.0
# T.Tagovailoa         MIA        0.271133          410.0
# J.Winston             NO        0.265811          381.0
# L.Jackson            BAL        0.252330          454.0
# T.Brady               TB        0.238825         1213.0
# Aa.Rodgers            GB        0.196977          143.0
# J.Love                GB        0.189867          132.0
# J.Garoppolo           LV        0.185440          984.0
# A.Rodgers             GB        0.172214          769.0
# C.Stroud             HOU        0.166537          221.0
# A.Luck               IND        0.150197          828.0
# J.Burrow             CIN        0.144420          873.0
# R.Fitzpatrick        WAS        0.136564          539.0
# J.Hurts              PHI        0.128291          345.0
# C.Palmer             ARI        0.121592          367.0
# K.Cousins            MIN        0.120600          822.0
# J.Allen              BUF        0.111988          647.0
# S.Bradford           ARI        0.103133          139.0
# D.Brees               NO        0.096325         1018.0
# C.Kessler            JAX        0.093733          110.0
# M.Ryan               IND        0.090768         1092.0
# E.Manning            NYG        0.089929          591.0
# J.Herbert            LAC        0.088641          829.0
# B.Roethlisberger     PIT        0.087983         1156.0
# A.Smith              WAS        0.086250          942.0
# J.Goff               DET        0.084074         1010.0
# M.Stafford            LA        0.073926          966.0
# D.Carr                NO        0.072533         2298.0
# P.Rivers             IND        0.070866         1716.0
# D.Watson             CLE        0.067253          690.0
# T.Taylor             NYG        0.050550          249.0
# R.Wilson             DEN        0.044900         1744.0
# C.Whitehurst         CLE        0.043893          103.0
# S.Hill               MIN        0.043786          102.0
# D.Prescott           DAL        0.041924          522.0
# K.Orton              BUF        0.035554          105.0
# J.Brissett           CLE        0.027119          518.0
# K.Murray             ARI        0.025132          779.0
# G.Minshew            IND        0.025067          295.0
# C.Wentz               LA        0.020908         1090.0
# R.Tannehill          TEN        0.016788         1309.0
# P.Manning            DEN        0.014715          408.0
# B.Mayfield            TB        0.010209          973.0
# L.Jones              PIT        0.008642          130.0
# G.Smith              SEA        0.005476          483.0
# M.Mariota            ATL        0.003577          881.0
# B.Bortles            JAX        0.001552          434.0
# J.Flacco             CLE       -0.002270          969.0
# B.Osweiler           MIA       -0.004542          212.0
# B.Hoyer               LV       -0.014520          363.0
# C.Newton             CAR       -0.016086         1037.0
# S.Howell             WAS       -0.016152          140.0
# A.Dalton              NO       -0.016423         1086.0
# T.Bridgewater        MIA       -0.026747          706.0
# T.Huntley            BAL       -0.028164          157.0
# D.Jones              NYG       -0.028801          284.0
# N.Mullens            MIN       -0.032546          192.0
# B.Gabbert             TB       -0.036236          229.0
# A.O'Connell           LV       -0.042705          168.0
# C.Keenum             CLE       -0.042940          525.0
# N.Foles              CHI       -0.057616          417.0
# C.Kaepernick          SF       -0.061038          371.0
# M.Sanchez            DAL       -0.081417          149.0
# T.Lawrence           JAX       -0.085860          293.0
# T.Siemian             NO       -0.092956          387.0
# D.Lock               SEA       -0.093128          438.0
# Z.Mettenberger       TEN       -0.101870          131.0
# J.Cutler             MIA       -0.108462          377.0
# J.Driskel            HOU       -0.114067          129.0
# M.Glennon            NYG       -0.120678          206.0
# M.Trubisky           PIT       -0.122446          359.0
# K.Allen              WAS       -0.129858          186.0
# D.Mills              HOU       -0.132116          347.0
# M.Jones               NE       -0.137052          391.0
# D.Stanton            ARI       -0.138421          158.0
# K.Pickett            PIT       -0.145120          231.0
# T.Savage             HOU       -0.148500          120.0
# J.Fields             CHI       -0.151065          332.0
# J.McCown             NYJ       -0.160934          460.0
# R.Mallett            HOU       -0.165347          120.0
# S.Darnold             SF       -0.165781          729.0
# C.Beathard            SF       -0.171062          203.0
# A.Davis              CLE       -0.179977          151.0
# T.Heinicke           WAS       -0.181954          284.0
# D.Kizer              CLE       -0.184073          175.0
# Z.Wilson             NYJ       -0.191950          507.0
# B.Young              CAR       -0.208110          153.0
# D.Haskins            WAS       -0.213901          179.0
# P.Walker             CLE       -0.236272          152.0
# J.Dobbs              MIN       -0.242151          113.0
# E.Manuel              LV       -0.279685          120.0
# J.Rosen              ARI       -0.321243          136.0
# D.Thompson-Robinson  CLE       -0.324328          115.0

# %%
pbp_grouped_cloudy = pbp_cloudy.groupby("passer_player_name").agg(team=('posteam', 'last'), mean_epa_cloudy=('epa', 'mean'), sum_att_cloudy=('pass_attempt', 'sum'))
pbp_filtered_cloudy = pbp_grouped_cloudy[pbp_grouped_cloudy["sum_att_cloudy"] > 50]
pd.set_option('display.max_rows', None)
pbp_filtered_cloudy = pbp_filtered_cloudy.sort_values(by="mean_epa_cloudy", ascending=False)
print(f"EPA in cloudy weather: {pbp_filtered_cloudy}")
# Out:
# EPA in cloudy weather:                    team  mean_epa_cloudy  sum_att_cloudy
# passer_player_name
# Jos.Allen           BUF         0.357568            55.0
# T.Romo              DAL         0.307713           239.0
# Aa.Rodgers           GB         0.306510            69.0
# J.Johnson            SF         0.247485            95.0
# P.Mahomes            KC         0.234076          1207.0
# C.Henne              KC         0.227590            58.0
# D.Mills             HOU         0.205575           159.0
# B.Purdy              SF         0.185875           302.0
# M.White             MIA         0.183492            64.0
# D.Brees              NO         0.177519          1780.0
# N.Mullens           MIN         0.160632           286.0
# A.Rodgers            GB         0.154775          1981.0
# J.Herbert           LAC         0.153909           713.0
# T.Brady              TB         0.143720          3246.0
# M.Stafford           LA         0.125878          1569.0
# B.Weeden            HOU         0.118531           114.0
# J.Hurts             PHI         0.113264           741.0
# B.Roethlisberger    PIT         0.109045          2338.0
# P.Manning           DEN         0.108895           467.0
# M.Ryan              IND         0.106950          1654.0
# D.Watson            CLE         0.102207          1258.0
# C.Palmer            ARI         0.101124           230.0
# P.Rivers            IND         0.100446          1559.0
# T.Taylor            NYG         0.097182           879.0
# R.Wilson            DEN         0.092778          2175.0
# G.Smith             SEA         0.088440           541.0
# J.Garoppolo          LV         0.087276           388.0
# J.Browning          CIN         0.083235           143.0
# J.Love               GB         0.076182           329.0
# M.Barkley           BUF         0.068863            84.0
# T.Tagovailoa        MIA         0.068696           956.0
# D.Lock              DEN         0.065021           193.0
# M.Hasselbeck        IND         0.064788           219.0
# R.Tannehill         TEN         0.063761          1903.0
# G.Minshew           IND         0.059357           299.0
# L.Jackson           BAL         0.059352          1155.0
# J.Allen             BUF         0.057668          1773.0
# A.Luck              IND         0.057518           980.0
# A.Dalton            CAR         0.055476          1830.0
# D.Prescott          DAL         0.054266           711.0
# M.Trubisky          PIT         0.054045           919.0
# K.Cousins           MIN         0.051429          1558.0
# D.Carr               NO         0.046217          1878.0
# R.Fitzpatrick       MIA         0.045946          1263.0
# J.Goff              DET         0.045064          1634.0
# T.Bridgewater       MIA         0.043543          1041.0
# M.Mariota           PHI         0.040926           753.0
# C.Wentz             WAS         0.035708          1311.0
# B.Mayfield           TB         0.029585          1468.0
# C.Daniel            LAC         0.026058           128.0
# C.Kaepernick         SF         0.025855           351.0
# M.Jones              NE         0.023103           577.0
# J.Burrow            CIN         0.019260           944.0
# J.McCown            PHI         0.017685           655.0
# T.Heinicke          ATL         0.016777           415.0
# K.Murray            ARI        -0.001485           589.0
# A.Smith             WAS        -0.005503          1168.0
# J.Winston            NO        -0.005581          1637.0
# E.Manning           NYG        -0.006146          1628.0
# B.Hoyer              LV        -0.006229           691.0
# A.O'Connell          LV        -0.012525           177.0
# W.Levis             TEN        -0.015014           176.0
# G.Minshew II        JAX        -0.020027           291.0
# C.Newton            CAR        -0.020938          1502.0
# M.Rudolph           PIT        -0.022229           256.0
# E.Stick             LAC        -0.025935            78.0
# J.Stidham           DEN        -0.026838           122.0
# M.Moore              KC        -0.034322           265.0
# J.Brissett          WAS        -0.041213           789.0
# N.Foles             CHI        -0.043561           622.0
# T.Lawrence          JAX        -0.047423           747.0
# J.Flacco            CLE        -0.047500          1625.0
# C.Beathard          JAX        -0.050469           139.0
# K.Pickett           PIT        -0.051600           383.0
# C.Keenum            HOU        -0.055189           760.0
# A.McCarron          CIN        -0.055917           186.0
# K.Orton             BUF        -0.058959           257.0
# T.Hill               NO        -0.062831            86.0
# B.Bortles            LA        -0.062921           677.0
# M.Sanchez           WAS        -0.067743           282.0
# T.Siemian           NYJ        -0.069354           659.0
# B.Hundley           ARI        -0.075940           126.0
# S.Darnold            SF        -0.080190           853.0
# R.Mallett           BAL        -0.082103           112.0
# S.Bradford          MIN        -0.089688           352.0
# B.Osweiler          MIA        -0.102944           810.0
# E.Manuel             LV        -0.107034           180.0
# D.Blough            ARI        -0.110218            91.0
# P.Lynch             DEN        -0.116719           120.0
# D.Jones             NYG        -0.120415           574.0
# J.Cutler            MIA        -0.125161           768.0
# B.Petty             NYJ        -0.130752           122.0
# D.Ridder            ATL        -0.131903           215.0
# K.Allen             HOU        -0.133783           430.0
# C.McCoy             ARI        -0.134158           216.0
# J.Fields            CHI        -0.139819           313.0
# D.Haskins           WAS        -0.141078           224.0
# D.Anderson          BUF        -0.143217            89.0
# C.Whitehurst        IND        -0.143404            92.0
# G.Gilbert           WAS        -0.157632            75.0
# T.Boyle             NYJ        -0.160257            70.0
# B.Gabbert            TB        -0.166720           241.0
# A.Davis             CLE        -0.166920            84.0
# C.Kessler           JAX        -0.172141           116.0
# J.Manziel           CLE        -0.173194           147.0
# D.Hodges            PIT        -0.176911            64.0
# M.Schaub            ATL        -0.181218            51.0
# J.Clausen           BAL        -0.192636            92.0
# Z.Wilson            NYJ        -0.193245           237.0
# J.Driskel           CLE        -0.206118           147.0
# J.Wolford            LA        -0.207031            79.0
# S.Howell            WAS        -0.207127           429.0
# B.Zappe              NE        -0.211851           151.0
# K.Hogan             CLE        -0.222368            72.0
# R.Griffin           BAL        -0.223957           325.0
# T.Savage            HOU        -0.231249           163.0
# B.Rypien             LA        -0.240482           114.0
# M.Glennon           NYG        -0.273248           273.0
# Z.Mettenberger      TEN        -0.282974           208.0
# M.Cassel            TEN        -0.283286           170.0
# J.Dobbs             MIN        -0.288422           118.0
# D.Kizer              GB        -0.289167           228.0
# T.Huntley           BAL        -0.301569           114.0
# J.Luton             JAX        -0.306170           118.0
# T.DeVito            NYG        -0.330508           115.0
# A.Brown             BAL        -0.340009            56.0
# B.Allen             CIN        -0.345977           165.0
# M.Vick              PIT        -0.349251           109.0
# B.Young             CAR        -0.388120           169.0
# S.Ehlinger          IND        -0.412351           100.0
# J.Rosen             ATL        -0.500827           146.0
# N.Peterman          CHI        -0.509421            82.0
# J.Locker            TEN        -0.586475            64.0
# L.Falk              NYJ        -0.707078            63.0
# P.Walker            CAR        -0.756319            61.0

# %%
pbp_grouped_rainy = pbp_rainy.groupby("passer_player_name").agg(team=('posteam', 'last'), mean_epa_rainy=('epa', 'mean'), sum_att_rainy=('pass_attempt', 'sum'))
pbp_filtered_rainy = pbp_grouped_rainy[pbp_grouped_rainy["sum_att_rainy"] > 20]
pd.set_option('display.max_rows', None)
pbp_filtered_rainy = pbp_filtered_rainy.sort_values(by="mean_epa_rainy", ascending=False)
print(f"EPA in rainy weather: {pbp_filtered_rainy}")
# Out:
# EPA in rainy weather:                    team  mean_epa_rainy  sum_att_rainy
# passer_player_name
# C.Stroud            HOU        0.430816           28.0
# J.Herbert           LAC        0.343959           70.0
# N.Foles             PHI        0.326944           37.0
# B.Purdy              SF        0.323384           77.0
# J.Burrow            CIN        0.311788           38.0
# D.Brees              NO        0.307457          216.0
# J.Garoppolo          SF        0.292898          104.0
# M.White             NYJ        0.254357           76.0
# B.Hoyer             HOU        0.253465           61.0
# T.Boyle             DET        0.194662           38.0
# K.Murray            ARI        0.188418           23.0
# M.Ryan              ATL        0.187720           76.0
# L.McCown             NO        0.185661           40.0
# M.Stafford           LA        0.170289          141.0
# T.Brady              TB        0.166234          488.0
# R.Fitzpatrick        TB        0.146743           94.0
# J.McCown            NYJ        0.137431           87.0
# K.Cousins           MIN        0.124657          156.0
# D.Ridder            ATL        0.124378           56.0
# K.Pickett           PIT        0.103440           52.0
# T.Bridgewater        NO        0.087399           57.0
# R.Tannehill         TEN        0.075049          186.0
# A.Rodgers           NYJ        0.057323          284.0
# A.Smith             WAS        0.046712          242.0
# C.Newton             NE        0.040076          181.0
# R.Mallett           HOU        0.036305           40.0
# J.Cutler            CHI        0.032004          148.0
# P.Rivers            LAC        0.027061           80.0
# A.Dalton             NO        0.026456          208.0
# D.Watson            HOU        0.021228           32.0
# R.Wilson            DEN        0.019598          461.0
# B.Roethlisberger    PIT        0.016313          305.0
# B.Hundley            GB        0.009476           54.0
# M.Rudolph           PIT        0.002660           44.0
# P.Mahomes            KC       -0.000279          100.0
# J.Love               GB       -0.003857           35.0
# C.Kaepernick         SF       -0.015469           35.0
# D.Carr               LV       -0.018622          198.0
# D.Prescott          DAL       -0.023800          160.0
# J.Allen             BUF       -0.027363          391.0
# A.Luck              IND       -0.046328          236.0
# G.Smith             SEA       -0.048359          175.0
# C.Wentz             PHI       -0.052001          423.0
# J.Goff               LA       -0.059589          127.0
# L.Jackson           BAL       -0.061934          320.0
# G.Minshew           IND       -0.071143          148.0
# E.Manning           NYG       -0.076523          277.0
# J.Browning          CIN       -0.091597           30.0
# T.Heinicke          ATL       -0.092242          123.0
# T.Lawrence          JAX       -0.103349           62.0
# J.Flacco            NYJ       -0.104043          272.0
# J.Brissett          CLE       -0.117943          119.0
# C.McCoy             ARI       -0.119478           37.0
# K.Moore             DAL       -0.128972           31.0
# M.Trubisky          PIT       -0.132104           97.0
# B.Young             CAR       -0.143848           27.0
# C.Keenum            CLE       -0.144514          153.0
# B.Bortles           JAX       -0.151006          471.0
# M.Jones              NE       -0.151929          101.0
# B.Mayfield           TB       -0.160295          182.0
# M.Mariota           ATL       -0.189577          241.0
# T.Taylor            NYG       -0.199406          218.0
# S.Darnold           CAR       -0.201251           55.0
# J.Dobbs             TEN       -0.205114           41.0
# J.Hurts             PHI       -0.207196          145.0
# J.Winston            NO       -0.211283          139.0
# D.Jones             NYG       -0.218316          238.0
# T.Tagovailoa        MIA       -0.220282           37.0
# B.Gabbert            TB       -0.223900           33.0
# M.Barkley           BUF       -0.226742           36.0
# J.Fields            CHI       -0.242411           90.0
# Z.Wilson            NYJ       -0.273405           63.0
# T.Huntley           BAL       -0.293470           66.0
# T.Siemian           CHI       -0.295868           70.0
# R.Griffin III       BAL       -0.303005           24.0
# T.Lance              SF       -0.304078           30.0
# B.Allen             CIN       -0.331203           34.0
# C.Ponder            MIN       -0.382283           50.0
# B.Petty             NYJ       -0.397545           46.0
# C.Beathard           SF       -0.436554           40.0
# D.Hodges            PIT       -0.471648           36.0
# D.Kizer             CLE       -0.474737           37.0
# B.Zappe              NE       -0.523994           30.0
# R.Lindley           ARI       -0.526281           32.0
# J.Fromm             NYG       -0.567110           34.0
# M.Cassel            DAL       -0.588682           31.0
# N.Peterman          BUF       -0.748368           30.0
# S.Howell            WAS       -0.820750           38.0

# %%
pbp_merged = pbp_filtered.merge(pbp_filtered_sunny, on=['passer_player_name', 'team'], how='left')
pbp_merged = pbp_merged.merge(pbp_filtered_cloudy, on=['passer_player_name', 'team'], how='left')
pbp_merged = pbp_merged.merge(pbp_filtered_rainy, on=['passer_player_name', 'team'], how='left')

print(pbp_merged)
# Out:
#                    team  mean_epa  sum_att  mean_epa_sunny  sum_att_sunny  \
# passer_player_name
# B.Purdy              SF  0.260180    833.0        0.368618          282.0
# P.Mahomes            KC  0.222529   4455.0        0.341232          962.0
# T.Romo              DAL  0.184863    655.0             NaN            NaN
# T.Brady              TB  0.156850   6715.0        0.238825         1213.0
# D.Brees              NO  0.155805   4176.0        0.096325         1018.0
# A.Rodgers           NYJ  0.137633   5241.0             NaN            NaN
# J.Garoppolo          LV  0.135447   2180.0        0.185440          984.0
# J.Love               GB  0.132817    754.0        0.189867          132.0
# P.Rivers            IND  0.126503   4393.0        0.070866         1716.0
# D.Prescott          DAL  0.111451   4417.0        0.041924          522.0
# B.Roethlisberger    PIT  0.108336   4707.0        0.087983         1156.0
# T.Tagovailoa        MIA  0.105459   1777.0        0.271133          410.0
# C.Stroud            HOU  0.105114    595.0        0.166537          221.0
# J.Allen             BUF  0.095079   3593.0        0.111988          647.0
# J.Burrow            CIN  0.094655   2332.0        0.144420          873.0
# M.Ryan              IND  0.093107   5712.0        0.090768         1092.0
# C.Palmer            ARI  0.089797   1814.0        0.121592          367.0
# L.Jackson           BAL  0.085586   2512.0        0.252330          454.0
# A.Luck              IND  0.083115   2396.0        0.150197          828.0
# J.Herbert           LAC  0.082497   2610.0        0.088641          829.0
# M.Stafford           LA  0.078851   5797.0        0.073926          966.0
# K.Cousins           MIN  0.078513   5456.0        0.120600          822.0
# D.Watson            CLE  0.077235   2450.0        0.067253          690.0
# N.Mullens           MIN  0.072826    854.0       -0.032546          192.0
# J.Goff              DET  0.068214   4671.0        0.084074         1010.0
# J.Winston            NO  0.063263   3095.0        0.265811          381.0
# R.Wilson            DEN  0.059658   5695.0        0.044900         1744.0
# R.Fitzpatrick       WAS  0.053812   2605.0        0.136564          539.0
# J.Hurts             PHI  0.050180   1872.0        0.128291          345.0
# A.Smith             WAS  0.046259   2863.0        0.086250          942.0
# P.Manning           DEN  0.041230   1114.0        0.014715          408.0
# R.Tannehill         TEN  0.034752   4140.0        0.016788         1309.0
# T.Bridgewater       MIA  0.031734   2268.0       -0.026747          706.0
# D.Carr               NO  0.030257   5879.0        0.072533         2298.0
# B.Mayfield           TB  0.021901   3213.0        0.010209          973.0
# G.Minshew           IND  0.021180   1001.0        0.025067          295.0
# C.Wentz              LA  0.012971   3582.0        0.020908         1090.0
# A.Dalton            CAR  0.012273   4119.0             NaN            NaN
# S.Bradford          ARI  0.008830   1285.0        0.103133          139.0
# K.Murray            ARI  0.004028   2440.0        0.025132          779.0
# G.Smith             SEA  0.003732   1809.0        0.005476          483.0
# M.Mariota           PHI  0.003280   2396.0             NaN            NaN
# E.Manning           NYG  0.002899   3326.0        0.089929          591.0
# C.Newton            CAR -0.005956   3445.0       -0.016086         1037.0
# T.Taylor            NYG -0.006422   1866.0        0.050550          249.0
# G.Minshew II        JAX -0.007967    540.0             NaN            NaN
# T.Lawrence          JAX -0.011095   1949.0       -0.085860          293.0
# M.Trubisky          PIT -0.015349   2086.0       -0.122446          359.0
# J.Flacco            CLE -0.021769   3703.0       -0.002270          969.0
# C.Keenum            HOU -0.035674   2188.0             NaN            NaN
# B.Hoyer              LV -0.037705   1487.0       -0.014520          363.0
# J.Brissett          WAS -0.039617   1735.0             NaN            NaN
# C.Kaepernick         SF -0.046495   1171.0       -0.061038          371.0
# J.Cutler            MIA -0.050037   1721.0       -0.108462          377.0
# M.Jones              NE -0.052849   1440.0       -0.137052          391.0
# D.Lock              SEA -0.054578    830.0       -0.093128          438.0
# M.Rudolph           PIT -0.058135    522.0             NaN            NaN
# B.Bortles            LA -0.062412   2935.0             NaN            NaN
# J.McCown            PHI -0.067327   1455.0             NaN            NaN
# K.Allen             LAC -0.069170    777.0             NaN            NaN
# T.Heinicke          ATL -0.071619   1085.0             NaN            NaN
# K.Pickett           PIT -0.072883    766.0       -0.145120          231.0
# D.Jones             NYG -0.073118   2160.0       -0.028801          284.0
# N.Foles             IND -0.082175   1773.0             NaN            NaN
# B.Osweiler          MIA -0.082361   1293.0       -0.004542          212.0
# D.Ridder            ATL -0.082549    546.0             NaN            NaN
# S.Darnold            SF -0.097508   1967.0       -0.165781          729.0
# C.McCoy             ARI -0.103051    572.0             NaN            NaN
# T.Siemian           NYJ -0.113514   1300.0             NaN            NaN
# D.Mills             HOU -0.132078    981.0       -0.132116          347.0
# C.Beathard          JAX -0.138630    620.0             NaN            NaN
# M.Glennon           NYG -0.158186    779.0       -0.120678          206.0
# J.Fields            CHI -0.177358   1099.0       -0.151065          332.0
# S.Howell            WAS -0.181072    701.0       -0.016152          140.0
# J.Dobbs             MIN -0.191945    541.0       -0.242151          113.0
# B.Gabbert            KC -0.191974    859.0             NaN            NaN
# Z.Wilson            NYJ -0.214129   1111.0       -0.191950          507.0
# B.Young             CAR -0.282304    590.0       -0.208110          153.0
# D.Kizer              GB -0.289987    560.0             NaN            NaN
# J.Rosen             ATL -0.388045    575.0             NaN            NaN
#
#                     mean_epa_cloudy  sum_att_cloudy  mean_epa_rainy  \
# passer_player_name
# B.Purdy                    0.185875           302.0        0.323384
# P.Mahomes                  0.234076          1207.0       -0.000279
# T.Romo                     0.307713           239.0             NaN
# T.Brady                    0.143720          3246.0        0.166234
# D.Brees                    0.177519          1780.0        0.307457
# A.Rodgers                       NaN             NaN        0.057323
# J.Garoppolo                0.087276           388.0             NaN
# J.Love                     0.076182           329.0       -0.003857
# P.Rivers                   0.100446          1559.0             NaN
# D.Prescott                 0.054266           711.0       -0.023800
# B.Roethlisberger           0.109045          2338.0        0.016313
# T.Tagovailoa               0.068696           956.0       -0.220282
# C.Stroud                        NaN             NaN        0.430816
# J.Allen                    0.057668          1773.0       -0.027363
# J.Burrow                   0.019260           944.0        0.311788
# M.Ryan                     0.106950          1654.0             NaN
# C.Palmer                   0.101124           230.0             NaN
# L.Jackson                  0.059352          1155.0       -0.061934
# A.Luck                     0.057518           980.0       -0.046328
# J.Herbert                  0.153909           713.0        0.343959
# M.Stafford                 0.125878          1569.0        0.170289
# K.Cousins                  0.051429          1558.0        0.124657
# D.Watson                   0.102207          1258.0             NaN
# N.Mullens                  0.160632           286.0             NaN
# J.Goff                     0.045064          1634.0             NaN
# J.Winston                 -0.005581          1637.0       -0.211283
# R.Wilson                   0.092778          2175.0        0.019598
# R.Fitzpatrick                   NaN             NaN             NaN
# J.Hurts                    0.113264           741.0       -0.207196
# A.Smith                   -0.005503          1168.0        0.046712
# P.Manning                  0.108895           467.0             NaN
# R.Tannehill                0.063761          1903.0        0.075049
# T.Bridgewater              0.043543          1041.0             NaN
# D.Carr                     0.046217          1878.0             NaN
# B.Mayfield                 0.029585          1468.0       -0.160295
# G.Minshew                  0.059357           299.0       -0.071143
# C.Wentz                         NaN             NaN             NaN
# A.Dalton                   0.055476          1830.0             NaN
# S.Bradford                      NaN             NaN             NaN
# K.Murray                  -0.001485           589.0        0.188418
# G.Smith                    0.088440           541.0       -0.048359
# M.Mariota                  0.040926           753.0             NaN
# E.Manning                 -0.006146          1628.0       -0.076523
# C.Newton                  -0.020938          1502.0             NaN
# T.Taylor                   0.097182           879.0       -0.199406
# G.Minshew II              -0.020027           291.0             NaN
# T.Lawrence                -0.047423           747.0       -0.103349
# M.Trubisky                 0.054045           919.0       -0.132104
# J.Flacco                  -0.047500          1625.0             NaN
# C.Keenum                  -0.055189           760.0             NaN
# B.Hoyer                   -0.006229           691.0             NaN
# J.Brissett                -0.041213           789.0             NaN
# C.Kaepernick               0.025855           351.0       -0.015469
# J.Cutler                  -0.125161           768.0             NaN
# M.Jones                    0.023103           577.0       -0.151929
# D.Lock                          NaN             NaN             NaN
# M.Rudolph                 -0.022229           256.0        0.002660
# B.Bortles                 -0.062921           677.0             NaN
# J.McCown                   0.017685           655.0             NaN
# K.Allen                         NaN             NaN             NaN
# T.Heinicke                 0.016777           415.0       -0.092242
# K.Pickett                 -0.051600           383.0        0.103440
# D.Jones                   -0.120415           574.0       -0.218316
# N.Foles                         NaN             NaN             NaN
# B.Osweiler                -0.102944           810.0             NaN
# D.Ridder                  -0.131903           215.0        0.124378
# S.Darnold                 -0.080190           853.0             NaN
# C.McCoy                   -0.134158           216.0       -0.119478
# T.Siemian                 -0.069354           659.0             NaN
# D.Mills                    0.205575           159.0             NaN
# C.Beathard                -0.050469           139.0             NaN
# M.Glennon                 -0.273248           273.0             NaN
# J.Fields                  -0.139819           313.0       -0.242411
# S.Howell                  -0.207127           429.0       -0.820750
# J.Dobbs                   -0.288422           118.0             NaN
# B.Gabbert                       NaN             NaN             NaN
# Z.Wilson                  -0.193245           237.0       -0.273405
# B.Young                   -0.388120           169.0       -0.143848
# D.Kizer                   -0.289167           228.0             NaN
# J.Rosen                   -0.500827           146.0             NaN
#
#                     sum_att_rainy
# passer_player_name
# B.Purdy                      77.0
# P.Mahomes                   100.0
# T.Romo                        NaN
# T.Brady                     488.0
# D.Brees                     216.0
# A.Rodgers                   284.0
# J.Garoppolo                   NaN
# J.Love                       35.0
# P.Rivers                      NaN
# D.Prescott                  160.0
# B.Roethlisberger            305.0
# T.Tagovailoa                 37.0
# C.Stroud                     28.0
# J.Allen                     391.0
# J.Burrow                     38.0
# M.Ryan                        NaN
# C.Palmer                      NaN
# L.Jackson                   320.0
# A.Luck                      236.0
# J.Herbert                    70.0
# M.Stafford                  141.0
# K.Cousins                   156.0
# D.Watson                      NaN
# N.Mullens                     NaN
# J.Goff                        NaN
# J.Winston                   139.0
# R.Wilson                    461.0
# R.Fitzpatrick                 NaN
# J.Hurts                     145.0
# A.Smith                     242.0
# P.Manning                     NaN
# R.Tannehill                 186.0
# T.Bridgewater                 NaN
# D.Carr                        NaN
# B.Mayfield                  182.0
# G.Minshew                   148.0
# C.Wentz                       NaN
# A.Dalton                      NaN
# S.Bradford                    NaN
# K.Murray                     23.0
# G.Smith                     175.0
# M.Mariota                     NaN
# E.Manning                   277.0
# C.Newton                      NaN
# T.Taylor                    218.0
# G.Minshew II                  NaN
# T.Lawrence                   62.0
# M.Trubisky                   97.0
# J.Flacco                      NaN
# C.Keenum                      NaN
# B.Hoyer                       NaN
# J.Brissett                    NaN
# C.Kaepernick                 35.0
# J.Cutler                      NaN
# M.Jones                     101.0
# D.Lock                        NaN
# M.Rudolph                    44.0
# B.Bortles                     NaN
# J.McCown                      NaN
# K.Allen                       NaN
# T.Heinicke                  123.0
# K.Pickett                    52.0
# D.Jones                     238.0
# N.Foles                       NaN
# B.Osweiler                    NaN
# D.Ridder                     56.0
# S.Darnold                     NaN
# C.McCoy                      37.0
# T.Siemian                     NaN
# D.Mills                       NaN
# C.Beathard                    NaN
# M.Glennon                     NaN
# J.Fields                     90.0
# S.Howell                     38.0
# J.Dobbs                       NaN
# B.Gabbert                     NaN
# Z.Wilson                     63.0
# B.Young                      27.0
# D.Kizer                       NaN
# J.Rosen                       NaN

# %% [markdown]
# ### Section 3 - Temperatures

# %% [markdown]
# Going back to the weather variable, we will take the temperature given. And we will look at games in below freezing weather vs. above freezing weather.

# %%
# Extract the temperature values directly before the degree symbol
pbp['temperature'] = pbp['weather'].str.extract(r'([-+]?\d+)(?=°)', expand=False)

# Convert the temperature column to numeric, handling NaN values
pbp['temperature'] = pd.to_numeric(pbp['temperature'], errors='coerce')

# Create the is_below_freezing column
pbp['is_below_freezing'] = pbp['temperature'] < 32

# Display the updated DataFrame
print(pbp.head())
# Out:
#     play_id          game_id old_game_id home_team away_team season_type  \
# 4      93.0  2014_01_BUF_CHI  2014090702       CHI       BUF         REG
# 7     162.0  2014_01_BUF_CHI  2014090702       CHI       BUF         REG
# 8     186.0  2014_01_BUF_CHI  2014090702       CHI       BUF         REG
# 9     210.0  2014_01_BUF_CHI  2014090702       CHI       BUF         REG
# 12    302.0  2014_01_BUF_CHI  2014090702       CHI       BUF         REG
#
#     week posteam posteam_type defteam  ... defense_coverage_type  \
# 4      1     BUF         away     CHI  ...                   NaN
# 7      1     CHI         home     BUF  ...                   NaN
# 8      1     CHI         home     BUF  ...                   NaN
# 9      1     CHI         home     BUF  ...                   NaN
# 12     1     BUF         away     CHI  ...                   NaN
#
#     first_word_weather is_sunny  is_cloudy  is_percipitation  temperature  \
# 4                Sunny        1          0                 0         74.0
# 7                Sunny        1          0                 0         74.0
# 8                Sunny        1          0                 0         74.0
# 9                Sunny        1          0                 0         74.0
# 12               Sunny        1          0                 0         74.0
#
#    is_below_freezing  is_cold  wind_speed  is_windy
# 4              False        0         3.0         0
# 7              False        0         3.0         0
# 8              False        0         3.0         0
# 9              False        0         3.0         0
# 12             False        0         3.0         0
#
# [5 rows x 399 columns]

# %%
pbp['temperature'] = pbp['weather'].str.extract(r'([-+]?\d+)(?=°)', expand=False)
pbp["temperature"] = pd.to_numeric(pbp['temperature'], errors='coerce')
pbp["is_cold"] = np.where(pbp["temperature"] <= 32, 1, 0)
print(pbp["is_cold"].mean())
pbp_cold = pbp[pbp["is_cold"] == 1]
mean_epa_cold = pbp.loc[pbp["is_cold"] == 1, "epa"].mean()
print(f"EPA in cold weather: {mean_epa_cold}")
# Out:
# 0.04917039132298807
# EPA in cold weather: -0.016088498756289482

# %% [markdown]
# As we can see here, the EPA decreases in cold weather just like it does in the rain. This makes sense with our original hypotheses.

# %%
pbp_grouped_cold = pbp_cold.groupby("passer_player_name").agg(team=('posteam', 'last'), mean_epa_cold=('epa', 'mean'), sum_att_cold=('pass_attempt', 'sum'))
pbp_filtered_cold = pbp_grouped_cold[pbp_grouped_cold["sum_att_cold"] > 50]
pd.set_option('display.max_rows', None)
pbp_filtered_cold = pbp_filtered_cold.sort_values(by="mean_epa_cold", ascending=False)
print(f"EPA in cold weather: {pbp_filtered_cold}")
# Out:
# EPA in cold weather:                    team  mean_epa_cold  sum_att_cold
# passer_player_name
# J.Love               GB       0.390115          75.0
# A.Rodgers            GB       0.221686         812.0
# L.Jackson           BAL       0.207006          51.0
# T.Brady              TB       0.173609         623.0
# P.Mahomes            KC       0.161765         608.0
# J.Burrow            CIN       0.157451         177.0
# D.Prescott          DAL       0.152289         124.0
# R.Tannehill         TEN       0.133957          90.0
# T.Taylor            BUF       0.127370         124.0
# M.Stafford           LA       0.094063         156.0
# M.Ryan              IND       0.086572         225.0
# J.Allen             BUF       0.084048         375.0
# M.Jones              NE       0.026854         121.0
# P.Rivers            LAC       0.021603          96.0
# B.Roethlisberger    PIT       0.013758         279.0
# B.Osweiler          DEN       0.011264         217.0
# K.Pickett           PIT      -0.010188          83.0
# A.Smith              KC      -0.032173         142.0
# K.Cousins           MIN      -0.034060         411.0
# A.Luck              IND      -0.035596         124.0
# J.Goff              DET      -0.037450         159.0
# J.Flacco            BAL      -0.045739         178.0
# C.Keenum            DEN      -0.046391          71.0
# T.Bridgewater       MIN      -0.058986         232.0
# N.Foles             IND      -0.073467         203.0
# J.Cutler            MIA      -0.073506         232.0
# B.Bortles           JAX      -0.074116          62.0
# D.Jones             NYG      -0.089183          83.0
# M.Trubisky          CHI      -0.091057         192.0
# R.Wilson            DEN      -0.092877         239.0
# J.Fields            CHI      -0.098023         127.0
# M.Mariota            LV      -0.099229         106.0
# J.Brissett          IND      -0.109647          80.0
# D.Watson            CLE      -0.113316         120.0
# C.Newton            CAR      -0.115096         164.0
# D.Carr               LV      -0.134079         244.0
# M.White             NYJ      -0.138897          58.0
# R.Griffin           CLE      -0.186595          64.0
# A.Dalton             NO      -0.202287         282.0
# D.Kizer              GB      -0.202746         140.0
# G.Smith             SEA      -0.202911          74.0
# B.Mayfield           LA      -0.211088          96.0
# T.Tagovailoa        MIA      -0.215005          74.0
# D.Lock              DEN      -0.220264         115.0
# J.Hurts             PHI      -0.230916          66.0
# B.Hundley            GB      -0.328948         132.0
# T.Siemian           DEN      -0.339545          55.0
# E.Manning           NYG      -0.389950         141.0

# %% [markdown]
# ### Section 4 - Wind

# %%
pbp['wind_speed'] = pbp['weather'].str.extract(r'(\d+)\s*mph')[0].astype(float)
pbp["wind_speed"] = pd.to_numeric(pbp['wind_speed'], errors='coerce')
pbp["wind_speed"].value_counts()
pbp["is_windy"] = np.where(pbp["wind_speed"] >= 15, 1, 0)
print(pbp["is_windy"].mean())
pbp_windy = pbp[pbp["is_windy"] == 1]
mean_epa_windy = pbp.loc[pbp["is_windy"] == 1, "epa"].mean()
print(f"EPA in windy weather: {mean_epa_windy}")
# Out:
# 0.08998802525045953
# EPA in windy weather: -0.018401216715574265

# %% [markdown]
# EPA also decreases in wind

# %%
pbp_grouped_windy = pbp_cold.groupby("passer_player_name").agg(team=('posteam', 'last'), mean_epa_wind=('epa', 'mean'), sum_att_wind=('pass_attempt', 'sum'))
pbp_filtered_windy = pbp_grouped_windy[pbp_grouped_windy["sum_att_wind"] > 50]
pd.set_option('display.max_rows', None)
pbp_filtered_windy = pbp_filtered_windy.sort_values(by="mean_epa_wind", ascending=False)
print(f"EPA in windy weather: {pbp_filtered_windy}")
# Out:
# EPA in windy weather:                    team  mean_epa_wind  sum_att_wind
# passer_player_name
# J.Love               GB       0.390115          75.0
# A.Rodgers            GB       0.221686         812.0
# L.Jackson           BAL       0.207006          51.0
# T.Brady              TB       0.173609         623.0
# P.Mahomes            KC       0.161765         608.0
# J.Burrow            CIN       0.157451         177.0
# D.Prescott          DAL       0.152289         124.0
# R.Tannehill         TEN       0.133957          90.0
# T.Taylor            BUF       0.127370         124.0
# M.Stafford           LA       0.094063         156.0
# M.Ryan              IND       0.086572         225.0
# J.Allen             BUF       0.084048         375.0
# M.Jones              NE       0.026854         121.0
# P.Rivers            LAC       0.021603          96.0
# B.Roethlisberger    PIT       0.013758         279.0
# B.Osweiler          DEN       0.011264         217.0
# K.Pickett           PIT      -0.010188          83.0
# A.Smith              KC      -0.032173         142.0
# K.Cousins           MIN      -0.034060         411.0
# A.Luck              IND      -0.035596         124.0
# J.Goff              DET      -0.037450         159.0
# J.Flacco            BAL      -0.045739         178.0
# C.Keenum            DEN      -0.046391          71.0
# T.Bridgewater       MIN      -0.058986         232.0
# N.Foles             IND      -0.073467         203.0
# J.Cutler            MIA      -0.073506         232.0
# B.Bortles           JAX      -0.074116          62.0
# D.Jones             NYG      -0.089183          83.0
# M.Trubisky          CHI      -0.091057         192.0
# R.Wilson            DEN      -0.092877         239.0
# J.Fields            CHI      -0.098023         127.0
# M.Mariota            LV      -0.099229         106.0
# J.Brissett          IND      -0.109647          80.0
# D.Watson            CLE      -0.113316         120.0
# C.Newton            CAR      -0.115096         164.0
# D.Carr               LV      -0.134079         244.0
# M.White             NYJ      -0.138897          58.0
# R.Griffin           CLE      -0.186595          64.0
# A.Dalton             NO      -0.202287         282.0
# D.Kizer              GB      -0.202746         140.0
# G.Smith             SEA      -0.202911          74.0
# B.Mayfield           LA      -0.211088          96.0
# T.Tagovailoa        MIA      -0.215005          74.0
# D.Lock              DEN      -0.220264         115.0
# J.Hurts             PHI      -0.230916          66.0
# B.Hundley            GB      -0.328948         132.0
# T.Siemian           DEN      -0.339545          55.0
# E.Manning           NYG      -0.389950         141.0

# %% [markdown]
# ### Section 5 - Regression + XGBoost

# %%
import statsmodels.api as sm

pbp_games = pbp.groupby(["game_id", "passer_player_name"]).agg(sum_epa=("epa", "sum"), att = ("pass_attempt", "sum"), yards = ("passing_yards", "sum"), mean_temp=("temperature", "mean"), is_sunny=("is_sunny","max"), is_cloudy=("is_cloudy","max"), is_rainy = ("is_percipitation", "max"), mean_wind = ("wind_speed", "mean"), is_cold = ("is_cold", "max"), is_windy = ("is_windy", "max")).reset_index()
pbp.columns
pbp_games.head(30)
pbp_games = pbp_games.dropna(subset=['sum_epa', 'yards', 'is_sunny', 'mean_temp', 'mean_wind', 'is_cloudy', 'is_rainy', 'is_cold', 'is_windy'])

y1 = pbp_games['sum_epa']
X1 = pbp_games[['is_rainy', 'mean_wind', "mean_temp"]]

# Adding a constant to the predictors for the intercept
X1 = sm.add_constant(X1)

# Performing OLS regression
model1 = sm.OLS(y1, X1).fit()

# Displaying the regression results
print(model1.summary())

y2 = pbp_games['sum_epa']
X2 = pbp_games[['is_sunny', 'mean_wind', "mean_temp"]]

# Adding a constant to the predictors for the intercept
X2 = sm.add_constant(X2)

# Performing OLS regression
model2 = sm.OLS(y2, X2).fit()

# Displaying the regression results
print(model2.summary())

y3 = pbp_games['sum_epa']
X3 = pbp_games[['is_cloudy', 'mean_wind', "mean_temp"]]

# Adding a constant to the predictors for the intercept
X3 = sm.add_constant(X3)

# Performing OLS regression
model3 = sm.OLS(y3, X3).fit()

# Displaying the regression results
print(model3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sum_epa   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     12.48
# Date:                Thu, 14 Nov 2024   Prob (F-statistic):           3.93e-08
# Time:                        11:17:32   Log-Likelihood:                -21464.
# No. Observations:                5790   AIC:                         4.294e+04
# Df Residuals:                    5786   BIC:                         4.296e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1482      0.543     -0.273      0.785      -1.214       0.917
# is_rainy      -1.8614      0.545     -3.415      0.001      -2.930      -0.793
# mean_wind     -0.0843      0.026     -3.259      0.001      -0.135      -0.034
# mean_temp      0.0242      0.008      3.160      0.002       0.009       0.039
# ==============================================================================
# Omnibus:                       29.798   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               38.766
# Skew:                          -0.073   Prob(JB):                     3.82e-09
# Kurtosis:                       3.374   Cond. No.                         275.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sum_epa   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     9.247
# Date:                Thu, 14 Nov 2024   Prob (F-statistic):           4.25e-06
# Time:                        11:17:32   Log-Likelihood:                -21468.
# No. Observations:                5790   AIC:                         4.294e+04
# Df Residuals:                    5786   BIC:                         4.297e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.4322      0.545     -0.793      0.428      -1.501       0.636
# is_sunny       0.3827      0.270      1.416      0.157      -0.147       0.912
# mean_wind     -0.0833      0.026     -3.208      0.001      -0.134      -0.032
# mean_temp      0.0245      0.008      3.178      0.001       0.009       0.040
# ==============================================================================
# Omnibus:                       28.260   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.638
# Skew:                          -0.068   Prob(JB):                     1.11e-08
# Kurtosis:                       3.365   Cond. No.                         263.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                sum_epa   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     9.199
# Date:                Thu, 14 Nov 2024   Prob (F-statistic):           4.55e-06
# Time:                        11:17:32   Log-Likelihood:                -21468.
# No. Observations:                5790   AIC:                         4.294e+04
# Df Residuals:                    5786   BIC:                         4.297e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.5039      0.554     -0.909      0.363      -1.591       0.583
# is_cloudy      0.3599      0.264      1.366      0.172      -0.157       0.877
# mean_wind     -0.0887      0.026     -3.422      0.001      -0.140      -0.038
# mean_temp      0.0264      0.008      3.438      0.001       0.011       0.041
# ==============================================================================
# Omnibus:                       28.087   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               36.320
# Skew:                          -0.069   Prob(JB):                     1.30e-08
# Kurtosis:                       3.363   Cond. No.                         269.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Cloudy and Sunny does not have an effect on weather. **But rain, wind speed, and temperature all do.**

# %%
import statsmodels.api as sm

pbp_games = pbp.groupby(["game_id", "passer_player_name"]).agg(sum_epa=("epa", "sum"), att = ("pass_attempt", "sum"), yards = ("passing_yards", "sum"), mean_temp=("temperature", "mean"), is_sunny=("is_sunny","max"), is_cloudy=("is_cloudy","max"), is_rainy = ("is_percipitation", "max"), mean_wind = ("wind_speed", "mean"), is_cold = ("is_cold", "max"), is_windy = ("is_windy", "max")).reset_index()
pbp.columns
pbp_games.head(30)
pbp_games = pbp_games.dropna(subset=['sum_epa', 'yards', 'is_sunny', 'mean_temp', 'mean_wind', 'is_cloudy', 'is_rainy', 'is_cold', 'is_windy'])

y4 = pbp_games['yards']
X4 = pbp_games[['is_rainy', 'mean_wind', "mean_temp"]]

# Adding a constant to the predictors for the intercept
X4 = sm.add_constant(X4)

# Performing OLS regression
model4 = sm.OLS(y4, X4).fit()

# Displaying the regression results
print(model4.summary())

y5 = pbp_games['yards']
X5 = pbp_games[['is_sunny', 'mean_wind', "mean_temp"]]

# Adding a constant to the predictors for the intercept
X5 = sm.add_constant(X5)

# Performing OLS regression
model5 = sm.OLS(y5, X5).fit()

# Displaying the regression results
print(model5.summary())

y6 = pbp_games['yards']
X6 = pbp_games[['is_cloudy', 'mean_wind', "mean_temp"]]

# Adding a constant to the predictors for the intercept
X6 = sm.add_constant(X6)

# Performing OLS regression
model6= sm.OLS(y6, X6).fit()

# Displaying the regression results
print(model6.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  yards   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     13.02
# Date:                Thu, 14 Nov 2024   Prob (F-statistic):           1.80e-08
# Time:                        11:17:35   Log-Likelihood:                -35364.
# No. Observations:                5790   AIC:                         7.074e+04
# Df Residuals:                    5786   BIC:                         7.076e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        184.4760      5.995     30.772      0.000     172.724     196.228
# is_rainy     -14.0109      6.013     -2.330      0.020     -25.798      -2.224
# mean_wind     -0.7082      0.285     -2.482      0.013      -1.268      -0.149
# mean_temp      0.3983      0.085      4.707      0.000       0.232       0.564
# ==============================================================================
# Omnibus:                      220.388   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              169.356
# Skew:                          -0.330   Prob(JB):                     1.68e-37
# Kurtosis:                       2.484   Cond. No.                         275.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  yards   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     11.20
# Date:                Thu, 14 Nov 2024   Prob (F-statistic):           2.52e-07
# Time:                        11:17:35   Log-Likelihood:                -35367.
# No. Observations:                5790   AIC:                         7.074e+04
# Df Residuals:                    5786   BIC:                         7.077e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        183.0461      6.011     30.452      0.000     171.262     194.830
# is_sunny       0.0009      2.980      0.000      1.000      -5.840       5.842
# mean_wind     -0.7253      0.286     -2.532      0.011      -1.287      -0.164
# mean_temp      0.4105      0.085      4.822      0.000       0.244       0.577
# ==============================================================================
# Omnibus:                      219.203   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              166.489
# Skew:                          -0.324   Prob(JB):                     7.04e-37
# Kurtosis:                       2.480   Cond. No.                         263.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  yards   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     12.01
# Date:                Thu, 14 Nov 2024   Prob (F-statistic):           7.73e-08
# Time:                        11:17:35   Log-Likelihood:                -35366.
# No. Observations:                5790   AIC:                         7.074e+04
# Df Residuals:                    5786   BIC:                         7.077e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        180.9591      6.113     29.601      0.000     168.975     192.943
# is_cloudy      4.5311      2.906      1.559      0.119      -1.165      10.228
# mean_wind     -0.7524      0.286     -2.632      0.009      -1.313      -0.192
# mean_temp      0.4172      0.085      4.931      0.000       0.251       0.583
# ==============================================================================
# Omnibus:                      217.636   Durbin-Watson:                   1.915
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              165.963
# Skew:                          -0.324   Prob(JB):                     9.15e-37
# Kurtosis:                       2.483   Cond. No.                         269.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
from sklearn.model_selection import train_test_split
pbp_games = pbp_games[pbp_games["att"] >= 10]
train_gbg1, test_gbg1 = train_test_split(pbp_games, test_size=0.2, random_state=42)
print("Training Set Shape:", train_gbg1.shape)
print("Test Set Shape:", test_gbg1.shape)
train_gbg1.head()
# Out:
# Training Set Shape: (3930, 12)
# Test Set Shape: (983, 12)
#               game_id passer_player_name    sum_epa   att  yards  mean_temp  \
# 4712   2021_06_GB_CHI         Aa.Rodgers   6.792426  26.0  195.0       62.0
# 586   2014_17_CIN_PIT           A.Dalton  -4.906590  41.0  244.0       37.0
# 1445   2016_06_DEN_SD           P.Rivers   2.645859  31.0  178.0       70.0
# 5792  2022_16_HOU_TEN           M.Willis -17.224499  27.0   99.0       20.0
# 4489  2020_18_IND_BUF           P.Rivers  14.806331  47.0  309.0       34.0
#
#       is_sunny  is_cloudy  is_rainy  mean_wind  is_cold  is_windy
# 4712         1          0         0        5.0        0         0
# 586          0          1         0        5.0        0         0
# 1445         0          0         0        9.0        0         0
# 5792         1          0         0       10.0        1         0
# 4489         1          0         0        6.0        0         0

# %%
import xgboost as xgb
train_gbg = train_gbg1.drop(train_gbg1.columns[[3, 4]], axis=1)
test_gbg = test_gbg1.drop(test_gbg1.columns[[3, 4]], axis=1)

train_desc = train_gbg.iloc[:, 0:2]

train_label = train_gbg["sum_epa"]

train_features = train_gbg.iloc[:, 3:]


test_desc = test_gbg.iloc[:, 0:2]

test_label = test_gbg["sum_epa"]

test_features = test_gbg.iloc[:, 3:]

# %%
total_na = test_gbg['sum_epa'].isna().sum()
print("Total NA values in column:", total_na)
# Out:
# Total NA values in column: 0

# %%
import xgboost as xgb
import pandas as pd
import numpy as np

# Prepare DMatrix for training and testing
dtrain = xgb.DMatrix(data=train_features, label=train_label)
dtest = xgb.DMatrix(data=test_features, label=test_label)

# Model parameters
param = {
    'max_depth': 3,
    'eta': 0.14,
    'objective': 'reg:squarederror',  # Regression objective
    'nthread': 4,
    'eval_metric': 'rmse'             # Use RMSE for regression
}

# Training parameters
num_boost_round = 500
early_stopping_rounds = 1
evallist = [(dtest, 'eval'), (dtrain, 'train')]

# Train the model
model = xgb.train(param, dtrain, num_boost_round, evals=evallist, early_stopping_rounds=early_stopping_rounds)
model.save_model('0001.model')

# Make predictions for test and train data
ypred_test = model.predict(dtest)
ypred_train = model.predict(dtrain)

# Create DataFrames for predictions and labels
pred_df_test = pd.DataFrame(ypred_test, columns=['predicted_values'])
pred_df_train = pd.DataFrame(ypred_train, columns=['predicted_values'])
test_label_df = test_label.reset_index(drop=True).to_frame(name="sum_epa")
train_label_df = train_label.reset_index(drop=True).to_frame(name="sum_epa")

# Concatenate the predictions with the original test features and labels
test_with_predictions = pd.concat([test_gbg.reset_index(drop=True), pred_df_test], axis=1)
train_with_predictions = pd.concat([train_gbg.reset_index(drop=True), pred_df_train], axis=1)

# Display the resulting DataFrame for test set
print("Test Data with Predictions:")
print(train_with_predictions.head())
# Out:
# [0]	eval-rmse:10.69672	train-rmse:10.61197
# [1]	eval-rmse:10.69392	train-rmse:10.59692
# [2]	eval-rmse:10.69094	train-rmse:10.58295
# [3]	eval-rmse:10.68699	train-rmse:10.57242
# [4]	eval-rmse:10.68847	train-rmse:10.56281
# [5]	eval-rmse:10.68364	train-rmse:10.55472
# [6]	eval-rmse:10.68037	train-rmse:10.54657
# [7]	eval-rmse:10.68405	train-rmse:10.53835
# [8]	eval-rmse:10.67718	train-rmse:10.53246
# [9]	eval-rmse:10.67934	train-rmse:10.52742
# [10]	eval-rmse:10.67562	train-rmse:10.52239
# [11]	eval-rmse:10.66835	train-rmse:10.51511
# [12]	eval-rmse:10.66255	train-rmse:10.51138
# [13]	eval-rmse:10.66906	train-rmse:10.50463
# [14]	eval-rmse:10.66481	train-rmse:10.50175
# [15]	eval-rmse:10.66475	train-rmse:10.49784
# [16]	eval-rmse:10.66881	train-rmse:10.49212
# [17]	eval-rmse:10.67100	train-rmse:10.48615
# [18]	eval-rmse:10.67056	train-rmse:10.48391
# [19]	eval-rmse:10.67352	train-rmse:10.47875
# [20]	eval-rmse:10.67766	train-rmse:10.47310
# [21]	eval-rmse:10.67829	train-rmse:10.46897
# [22]	eval-rmse:10.67812	train-rmse:10.46449
# [23]	eval-rmse:10.68008	train-rmse:10.45995
# [24]	eval-rmse:10.68028	train-rmse:10.45793
# [25]	eval-rmse:10.68014	train-rmse:10.45643
# [26]	eval-rmse:10.67874	train-rmse:10.45158
# [27]	eval-rmse:10.67970	train-rmse:10.44685
# [28]	eval-rmse:10.67852	train-rmse:10.44397
# [29]	eval-rmse:10.67875	train-rmse:10.44264
# [30]	eval-rmse:10.67865	train-rmse:10.44118
# [31]	eval-rmse:10.68114	train-rmse:10.43895
# [32]	eval-rmse:10.68150	train-rmse:10.43508
# [33]	eval-rmse:10.68019	train-rmse:10.43045
# [34]	eval-rmse:10.68283	train-rmse:10.42708
# [35]	eval-rmse:10.68312	train-rmse:10.42282
# [36]	eval-rmse:10.68543	train-rmse:10.41955
# [37]	eval-rmse:10.68621	train-rmse:10.41581
# [38]	eval-rmse:10.68696	train-rmse:10.41313
# [39]	eval-rmse:10.68746	train-rmse:10.41210
# [40]	eval-rmse:10.68684	train-rmse:10.40850
# [41]	eval-rmse:10.69085	train-rmse:10.40537
# [42]	eval-rmse:10.69149	train-rmse:10.40288
# [43]	eval-rmse:10.69004	train-rmse:10.39994
# [44]	eval-rmse:10.69061	train-rmse:10.39937
# [45]	eval-rmse:10.69159	train-rmse:10.39732
# [46]	eval-rmse:10.69116	train-rmse:10.39388
# [47]	eval-rmse:10.69169	train-rmse:10.39178
# [48]	eval-rmse:10.69212	train-rmse:10.38932
# [49]	eval-rmse:10.69341	train-rmse:10.38856
# [50]	eval-rmse:10.69533	train-rmse:10.38591
# [51]	eval-rmse:10.69618	train-rmse:10.38302
# [52]	eval-rmse:10.69373	train-rmse:10.38021
# [53]	eval-rmse:10.69486	train-rmse:10.37888
# [54]	eval-rmse:10.69664	train-rmse:10.37814
# [55]	eval-rmse:10.69578	train-rmse:10.37572
# [56]	eval-rmse:10.69667	train-rmse:10.37416
# [57]	eval-rmse:10.69679	train-rmse:10.37240
# [58]	eval-rmse:10.69826	train-rmse:10.37010
# [59]	eval-rmse:10.69921	train-rmse:10.36866
# [60]	eval-rmse:10.69945	train-rmse:10.36804
# [61]	eval-rmse:10.69957	train-rmse:10.36452
# [62]	eval-rmse:10.69980	train-rmse:10.36022
# [63]	eval-rmse:10.70189	train-rmse:10.35701
# [64]	eval-rmse:10.70242	train-rmse:10.35638
# [65]	eval-rmse:10.70445	train-rmse:10.35394
# [66]	eval-rmse:10.70391	train-rmse:10.35349
# [67]	eval-rmse:10.70366	train-rmse:10.35293
# [68]	eval-rmse:10.70276	train-rmse:10.35180
# [69]	eval-rmse:10.70124	train-rmse:10.34878
# [70]	eval-rmse:10.70204	train-rmse:10.34485
# [71]	eval-rmse:10.70667	train-rmse:10.34074
# [72]	eval-rmse:10.70670	train-rmse:10.34013
# [73]	eval-rmse:10.70486	train-rmse:10.33682
# [74]	eval-rmse:10.71061	train-rmse:10.33228
# [75]	eval-rmse:10.71639	train-rmse:10.32871
# [76]	eval-rmse:10.71659	train-rmse:10.32805
# [77]	eval-rmse:10.71774	train-rmse:10.32618
# [78]	eval-rmse:10.71791	train-rmse:10.32432
# [79]	eval-rmse:10.72311	train-rmse:10.32150
# [80]	eval-rmse:10.72337	train-rmse:10.32110
# [81]	eval-rmse:10.72357	train-rmse:10.32056
# [82]	eval-rmse:10.72458	train-rmse:10.31793
# [83]	eval-rmse:10.72493	train-rmse:10.31605
# [84]	eval-rmse:10.72407	train-rmse:10.31320
# [85]	eval-rmse:10.72582	train-rmse:10.31079
# [86]	eval-rmse:10.72591	train-rmse:10.31034
# [87]	eval-rmse:10.72612	train-rmse:10.30990
# [88]	eval-rmse:10.72520	train-rmse:10.30713
# [89]	eval-rmse:10.72843	train-rmse:10.30485
# [90]	eval-rmse:10.72757	train-rmse:10.30257
# [91]	eval-rmse:10.72839	train-rmse:10.30120
# [92]	eval-rmse:10.72880	train-rmse:10.29907
# [93]	eval-rmse:10.73097	train-rmse:10.29576
# [94]	eval-rmse:10.73435	train-rmse:10.29394
# [95]	eval-rmse:10.73598	train-rmse:10.29159
# [96]	eval-rmse:10.73645	train-rmse:10.29026
# [97]	eval-rmse:10.73660	train-rmse:10.28817
# [98]	eval-rmse:10.73870	train-rmse:10.28561
# [99]	eval-rmse:10.73891	train-rmse:10.28523
# [100]	eval-rmse:10.74263	train-rmse:10.28304
# [101]	eval-rmse:10.74302	train-rmse:10.28272
# [102]	eval-rmse:10.74276	train-rmse:10.28168
# [103]	eval-rmse:10.74656	train-rmse:10.27938
# [104]	eval-rmse:10.74680	train-rmse:10.27907
# [105]	eval-rmse:10.74412	train-rmse:10.27663
# [106]	eval-rmse:10.74355	train-rmse:10.27601
# [107]	eval-rmse:10.74639	train-rmse:10.27285
# [108]	eval-rmse:10.74705	train-rmse:10.27258
# [109]	eval-rmse:10.74623	train-rmse:10.27092
# [110]	eval-rmse:10.74516	train-rmse:10.26913
# [111]	eval-rmse:10.74580	train-rmse:10.26892
# [112]	eval-rmse:10.74570	train-rmse:10.26763
# [113]	eval-rmse:10.74509	train-rmse:10.26736
# [114]	eval-rmse:10.74576	train-rmse:10.26544
# [115]	eval-rmse:10.74406	train-rmse:10.26292
# [116]	eval-rmse:10.74410	train-rmse:10.26273
# [117]	eval-rmse:10.74502	train-rmse:10.26067
# [118]	eval-rmse:10.74733	train-rmse:10.25901
# [119]	eval-rmse:10.74801	train-rmse:10.25651
# [120]	eval-rmse:10.74894	train-rmse:10.25407
# [121]	eval-rmse:10.74989	train-rmse:10.25199
# [122]	eval-rmse:10.75100	train-rmse:10.25047
# [123]	eval-rmse:10.75439	train-rmse:10.24823
# [124]	eval-rmse:10.75479	train-rmse:10.24529
# [125]	eval-rmse:10.75432	train-rmse:10.24507
# [126]	eval-rmse:10.75404	train-rmse:10.24308
# [127]	eval-rmse:10.75307	train-rmse:10.24072
# [128]	eval-rmse:10.75323	train-rmse:10.24036
# [129]	eval-rmse:10.75620	train-rmse:10.23846
# [130]	eval-rmse:10.75745	train-rmse:10.23735
# [131]	eval-rmse:10.75781	train-rmse:10.23627
# [132]	eval-rmse:10.75790	train-rmse:10.23615
# [133]	eval-rmse:10.75890	train-rmse:10.23511
# [134]	eval-rmse:10.75911	train-rmse:10.23486
# [135]	eval-rmse:10.76503	train-rmse:10.23048
# [136]	eval-rmse:10.76544	train-rmse:10.22964
# [137]	eval-rmse:10.76612	train-rmse:10.22787
# [138]	eval-rmse:10.76763	train-rmse:10.22679
# [139]	eval-rmse:10.76813	train-rmse:10.22451
# [140]	eval-rmse:10.76747	train-rmse:10.22398
# [141]	eval-rmse:10.76683	train-rmse:10.22367
# [142]	eval-rmse:10.76722	train-rmse:10.22273
# [143]	eval-rmse:10.76937	train-rmse:10.22091
# [144]	eval-rmse:10.76922	train-rmse:10.21706
# [145]	eval-rmse:10.76867	train-rmse:10.21642
# [146]	eval-rmse:10.76831	train-rmse:10.21629
# [147]	eval-rmse:10.76768	train-rmse:10.21510
# [148]	eval-rmse:10.76669	train-rmse:10.21443
# [149]	eval-rmse:10.76929	train-rmse:10.21258
# [150]	eval-rmse:10.77146	train-rmse:10.21095
# [151]	eval-rmse:10.77253	train-rmse:10.20927
# [152]	eval-rmse:10.77338	train-rmse:10.20656
# [153]	eval-rmse:10.77487	train-rmse:10.20567
# [154]	eval-rmse:10.77567	train-rmse:10.20472
# [155]	eval-rmse:10.77535	train-rmse:10.20461
# [156]	eval-rmse:10.77454	train-rmse:10.20309
# [157]	eval-rmse:10.77541	train-rmse:10.20157
# [158]	eval-rmse:10.77485	train-rmse:10.20135
# [159]	eval-rmse:10.77741	train-rmse:10.20050
# [160]	eval-rmse:10.77667	train-rmse:10.20032
# [161]	eval-rmse:10.77696	train-rmse:10.20016
# [162]	eval-rmse:10.77778	train-rmse:10.19838
# [163]	eval-rmse:10.77782	train-rmse:10.19604
# [164]	eval-rmse:10.77981	train-rmse:10.19458
# [165]	eval-rmse:10.78275	train-rmse:10.19283
# [166]	eval-rmse:10.78561	train-rmse:10.19011
# [167]	eval-rmse:10.78425	train-rmse:10.18818
# [168]	eval-rmse:10.78299	train-rmse:10.18667
# [169]	eval-rmse:10.78377	train-rmse:10.18571
# [170]	eval-rmse:10.78323	train-rmse:10.18414
# [171]	eval-rmse:10.78333	train-rmse:10.18402
# [172]	eval-rmse:10.78395	train-rmse:10.18291
# [173]	eval-rmse:10.78335	train-rmse:10.18277
# [174]	eval-rmse:10.78360	train-rmse:10.18265
# [175]	eval-rmse:10.78600	train-rmse:10.18101
# [176]	eval-rmse:10.78626	train-rmse:10.18023
# [177]	eval-rmse:10.78969	train-rmse:10.17835
# [178]	eval-rmse:10.79127	train-rmse:10.17668
# [179]	eval-rmse:10.79403	train-rmse:10.17454
# [180]	eval-rmse:10.79710	train-rmse:10.17341
# [181]	eval-rmse:10.79639	train-rmse:10.17238
# [182]	eval-rmse:10.79874	train-rmse:10.17045
# [183]	eval-rmse:10.79786	train-rmse:10.16999
# [184]	eval-rmse:10.79732	train-rmse:10.16859
# [185]	eval-rmse:10.79928	train-rmse:10.16744
# [186]	eval-rmse:10.79850	train-rmse:10.16703
# [187]	eval-rmse:10.79917	train-rmse:10.16630
# [188]	eval-rmse:10.79937	train-rmse:10.16621
# [189]	eval-rmse:10.79945	train-rmse:10.16611
# [190]	eval-rmse:10.80027	train-rmse:10.16298
# [191]	eval-rmse:10.80144	train-rmse:10.16199
# [192]	eval-rmse:10.80150	train-rmse:10.16191
# [193]	eval-rmse:10.80111	train-rmse:10.16036
# [194]	eval-rmse:10.80309	train-rmse:10.15914
# [195]	eval-rmse:10.80391	train-rmse:10.15672
# [196]	eval-rmse:10.80498	train-rmse:10.15566
# [197]	eval-rmse:10.80562	train-rmse:10.15508
# [198]	eval-rmse:10.80699	train-rmse:10.15418
# [199]	eval-rmse:10.80733	train-rmse:10.15413
# [200]	eval-rmse:10.80989	train-rmse:10.15236
# [201]	eval-rmse:10.80966	train-rmse:10.15205
# [202]	eval-rmse:10.80910	train-rmse:10.15194
# [203]	eval-rmse:10.81170	train-rmse:10.15019
# [204]	eval-rmse:10.81152	train-rmse:10.14994
# [205]	eval-rmse:10.81158	train-rmse:10.14987
# [206]	eval-rmse:10.81055	train-rmse:10.14877
# [207]	eval-rmse:10.81084	train-rmse:10.14849
# [208]	eval-rmse:10.81141	train-rmse:10.14807
# [209]	eval-rmse:10.81279	train-rmse:10.14670
# [210]	eval-rmse:10.81410	train-rmse:10.14550
# [211]	eval-rmse:10.81360	train-rmse:10.14542
# [212]	eval-rmse:10.81315	train-rmse:10.14534
# [213]	eval-rmse:10.81329	train-rmse:10.14514
# [214]	eval-rmse:10.81450	train-rmse:10.14411
# [215]	eval-rmse:10.81697	train-rmse:10.14273
# [216]	eval-rmse:10.81874	train-rmse:10.14146
# [217]	eval-rmse:10.81935	train-rmse:10.13986
# [218]	eval-rmse:10.81645	train-rmse:10.13825
# [219]	eval-rmse:10.81729	train-rmse:10.13726
# [220]	eval-rmse:10.81701	train-rmse:10.13623
# [221]	eval-rmse:10.81740	train-rmse:10.13458
# [222]	eval-rmse:10.82046	train-rmse:10.13325
# [223]	eval-rmse:10.82155	train-rmse:10.13190
# [224]	eval-rmse:10.82209	train-rmse:10.13024
# [225]	eval-rmse:10.82278	train-rmse:10.12932
# [226]	eval-rmse:10.82333	train-rmse:10.12814
# [227]	eval-rmse:10.82331	train-rmse:10.12661
# [228]	eval-rmse:10.82417	train-rmse:10.12530
# [229]	eval-rmse:10.82384	train-rmse:10.12510
# [230]	eval-rmse:10.82210	train-rmse:10.12354
# [231]	eval-rmse:10.82256	train-rmse:10.12142
# [232]	eval-rmse:10.82193	train-rmse:10.12024
# [233]	eval-rmse:10.82300	train-rmse:10.11961
# [234]	eval-rmse:10.82305	train-rmse:10.11946
# [235]	eval-rmse:10.82554	train-rmse:10.11851
# [236]	eval-rmse:10.82708	train-rmse:10.11687
# [237]	eval-rmse:10.82849	train-rmse:10.11468
# [238]	eval-rmse:10.82994	train-rmse:10.11353
# [239]	eval-rmse:10.83080	train-rmse:10.11042
# [240]	eval-rmse:10.83066	train-rmse:10.10901
# [241]	eval-rmse:10.83074	train-rmse:10.10895
# [242]	eval-rmse:10.83036	train-rmse:10.10881
# [243]	eval-rmse:10.82888	train-rmse:10.10786
# [244]	eval-rmse:10.82975	train-rmse:10.10601
# [245]	eval-rmse:10.83234	train-rmse:10.10476
# [246]	eval-rmse:10.83225	train-rmse:10.10419
# [247]	eval-rmse:10.83296	train-rmse:10.10329
# [248]	eval-rmse:10.83523	train-rmse:10.10270
# [249]	eval-rmse:10.83753	train-rmse:10.10188
# [250]	eval-rmse:10.83892	train-rmse:10.10052
# [251]	eval-rmse:10.84079	train-rmse:10.09845
# [252]	eval-rmse:10.84100	train-rmse:10.09652
# [253]	eval-rmse:10.84090	train-rmse:10.09490
# [254]	eval-rmse:10.84131	train-rmse:10.09362
# [255]	eval-rmse:10.84306	train-rmse:10.09204
# [256]	eval-rmse:10.84424	train-rmse:10.09120
# [257]	eval-rmse:10.84523	train-rmse:10.09093
# [258]	eval-rmse:10.84939	train-rmse:10.08844
# [259]	eval-rmse:10.85322	train-rmse:10.08727
# [260]	eval-rmse:10.85258	train-rmse:10.08694
# [261]	eval-rmse:10.85319	train-rmse:10.08555
# [262]	eval-rmse:10.85510	train-rmse:10.08470
# [263]	eval-rmse:10.85652	train-rmse:10.08371
# [264]	eval-rmse:10.85916	train-rmse:10.08065
# [265]	eval-rmse:10.85762	train-rmse:10.07965
# [266]	eval-rmse:10.85960	train-rmse:10.07890
# [267]	eval-rmse:10.85933	train-rmse:10.07659
# [268]	eval-rmse:10.85911	train-rmse:10.07609
# [269]	eval-rmse:10.85919	train-rmse:10.07603
# [270]	eval-rmse:10.86013	train-rmse:10.07557
# [271]	eval-rmse:10.85947	train-rmse:10.07372
# [272]	eval-rmse:10.86006	train-rmse:10.07289
# [273]	eval-rmse:10.86081	train-rmse:10.07234
# [274]	eval-rmse:10.86325	train-rmse:10.07132
# [275]	eval-rmse:10.86225	train-rmse:10.07105
# [276]	eval-rmse:10.86402	train-rmse:10.06972
# [277]	eval-rmse:10.86357	train-rmse:10.06967
# [278]	eval-rmse:10.86466	train-rmse:10.06900
# [279]	eval-rmse:10.86592	train-rmse:10.06681
# [280]	eval-rmse:10.86568	train-rmse:10.06565
# [281]	eval-rmse:10.86632	train-rmse:10.06396
# [282]	eval-rmse:10.86566	train-rmse:10.06165
# [283]	eval-rmse:10.86476	train-rmse:10.06086
# [284]	eval-rmse:10.86410	train-rmse:10.06044
# [285]	eval-rmse:10.86400	train-rmse:10.06038
# [286]	eval-rmse:10.86526	train-rmse:10.05900
# [287]	eval-rmse:10.86568	train-rmse:10.05773
# [288]	eval-rmse:10.86955	train-rmse:10.05537
# [289]	eval-rmse:10.87091	train-rmse:10.05440
# [290]	eval-rmse:10.87320	train-rmse:10.05294
# [291]	eval-rmse:10.87444	train-rmse:10.05254
# [292]	eval-rmse:10.87444	train-rmse:10.05155
# [293]	eval-rmse:10.87482	train-rmse:10.05086
# [294]	eval-rmse:10.87440	train-rmse:10.04997
# [295]	eval-rmse:10.87387	train-rmse:10.04980
# [296]	eval-rmse:10.87760	train-rmse:10.04840
# [297]	eval-rmse:10.87889	train-rmse:10.04705
# [298]	eval-rmse:10.87915	train-rmse:10.04688
# [299]	eval-rmse:10.87883	train-rmse:10.04609
# [300]	eval-rmse:10.87881	train-rmse:10.04592
# [301]	eval-rmse:10.87844	train-rmse:10.04587
# [302]	eval-rmse:10.87812	train-rmse:10.04574
# [303]	eval-rmse:10.87819	train-rmse:10.04567
# [304]	eval-rmse:10.87835	train-rmse:10.04505
# [305]	eval-rmse:10.87749	train-rmse:10.04428
# [306]	eval-rmse:10.87919	train-rmse:10.04406
# [307]	eval-rmse:10.87911	train-rmse:10.04350
# [308]	eval-rmse:10.87915	train-rmse:10.04339
# [309]	eval-rmse:10.87860	train-rmse:10.04283
# [310]	eval-rmse:10.87997	train-rmse:10.04170
# [311]	eval-rmse:10.87864	train-rmse:10.04116
# [312]	eval-rmse:10.87832	train-rmse:10.03968
# [313]	eval-rmse:10.88000	train-rmse:10.03889
# [314]	eval-rmse:10.88018	train-rmse:10.03830
# [315]	eval-rmse:10.88103	train-rmse:10.03730
# [316]	eval-rmse:10.88582	train-rmse:10.03618
# [317]	eval-rmse:10.88551	train-rmse:10.03564
# [318]	eval-rmse:10.88660	train-rmse:10.03348
# [319]	eval-rmse:10.88974	train-rmse:10.03158
# [320]	eval-rmse:10.89150	train-rmse:10.03048
# [321]	eval-rmse:10.89327	train-rmse:10.02901
# [322]	eval-rmse:10.89374	train-rmse:10.02842
# [323]	eval-rmse:10.89413	train-rmse:10.02796
# [324]	eval-rmse:10.89486	train-rmse:10.02708
# [325]	eval-rmse:10.89719	train-rmse:10.02434
# [326]	eval-rmse:10.89670	train-rmse:10.02354
# [327]	eval-rmse:10.89768	train-rmse:10.02292
# [328]	eval-rmse:10.89896	train-rmse:10.02194
# [329]	eval-rmse:10.89960	train-rmse:10.02046
# [330]	eval-rmse:10.89975	train-rmse:10.01954
# [331]	eval-rmse:10.89954	train-rmse:10.01820
# [332]	eval-rmse:10.89999	train-rmse:10.01608
# [333]	eval-rmse:10.90193	train-rmse:10.01444
# [334]	eval-rmse:10.90192	train-rmse:10.01400
# [335]	eval-rmse:10.90358	train-rmse:10.01260
# [336]	eval-rmse:10.90547	train-rmse:10.01126
# [337]	eval-rmse:10.90628	train-rmse:10.01063
# [338]	eval-rmse:10.90770	train-rmse:10.00970
# [339]	eval-rmse:10.90928	train-rmse:10.00823
# [340]	eval-rmse:10.91016	train-rmse:10.00640
# [341]	eval-rmse:10.91144	train-rmse:10.00451
# [342]	eval-rmse:10.91013	train-rmse:10.00389
# [343]	eval-rmse:10.91161	train-rmse:10.00282
# [344]	eval-rmse:10.91407	train-rmse:10.00216
# [345]	eval-rmse:10.91496	train-rmse:10.00131
# [346]	eval-rmse:10.91557	train-rmse:10.00039
# [347]	eval-rmse:10.91595	train-rmse:9.99999
# [348]	eval-rmse:10.91729	train-rmse:9.99909
# [349]	eval-rmse:10.91673	train-rmse:9.99824
# [350]	eval-rmse:10.91692	train-rmse:9.99756
# [351]	eval-rmse:10.91588	train-rmse:9.99661
# [352]	eval-rmse:10.91528	train-rmse:9.99543
# [353]	eval-rmse:10.91454	train-rmse:9.99451
# [354]	eval-rmse:10.91432	train-rmse:9.99336
# [355]	eval-rmse:10.91972	train-rmse:9.99183
# [356]	eval-rmse:10.92012	train-rmse:9.99149
# [357]	eval-rmse:10.92243	train-rmse:9.99027
# [358]	eval-rmse:10.92528	train-rmse:9.98906
# [359]	eval-rmse:10.92506	train-rmse:9.98756
# [360]	eval-rmse:10.92507	train-rmse:9.98631
# [361]	eval-rmse:10.92716	train-rmse:9.98548
# [362]	eval-rmse:10.92851	train-rmse:9.98371
# [363]	eval-rmse:10.92896	train-rmse:9.98234
# [364]	eval-rmse:10.92998	train-rmse:9.98115
# [365]	eval-rmse:10.93084	train-rmse:9.97975
# [366]	eval-rmse:10.93086	train-rmse:9.97968
# [367]	eval-rmse:10.93088	train-rmse:9.97963
# [368]	eval-rmse:10.93191	train-rmse:9.97819
# [369]	eval-rmse:10.93247	train-rmse:9.97766
# [370]	eval-rmse:10.93312	train-rmse:9.97715
# [371]	eval-rmse:10.93402	train-rmse:9.97634
# [372]	eval-rmse:10.93606	train-rmse:9.97511
# [373]	eval-rmse:10.93589	train-rmse:9.97506
# [374]	eval-rmse:10.93589	train-rmse:9.97501
# [375]	eval-rmse:10.93592	train-rmse:9.97497
# [376]	eval-rmse:10.93596	train-rmse:9.97422
# [377]	eval-rmse:10.93630	train-rmse:9.97318
# [378]	eval-rmse:10.93801	train-rmse:9.97196
# [379]	eval-rmse:10.94016	train-rmse:9.97093
# [380]	eval-rmse:10.94116	train-rmse:9.97021
# [381]	eval-rmse:10.94185	train-rmse:9.96898
# [382]	eval-rmse:10.94412	train-rmse:9.96804
# [383]	eval-rmse:10.94397	train-rmse:9.96800
# [384]	eval-rmse:10.94461	train-rmse:9.96686
# [385]	eval-rmse:10.94391	train-rmse:9.96627
# [386]	eval-rmse:10.94389	train-rmse:9.96520
# [387]	eval-rmse:10.94443	train-rmse:9.96442
# [388]	eval-rmse:10.94426	train-rmse:9.96438
# [389]	eval-rmse:10.94510	train-rmse:9.96355
# [390]	eval-rmse:10.94651	train-rmse:9.96256
# [391]	eval-rmse:10.94635	train-rmse:9.96162
# [392]	eval-rmse:10.94587	train-rmse:9.96088
# [393]	eval-rmse:10.94754	train-rmse:9.95952
# [394]	eval-rmse:10.94776	train-rmse:9.95893
# [395]	eval-rmse:10.94828	train-rmse:9.95835
# [396]	eval-rmse:10.94857	train-rmse:9.95776
# [397]	eval-rmse:10.94855	train-rmse:9.95773
# [398]	eval-rmse:10.95007	train-rmse:9.95680
# [399]	eval-rmse:10.95286	train-rmse:9.95528
# [400]	eval-rmse:10.95267	train-rmse:9.95487
# [401]	eval-rmse:10.95531	train-rmse:9.95370
# [402]	eval-rmse:10.95528	train-rmse:9.95338
# [403]	eval-rmse:10.95617	train-rmse:9.95218
# [404]	eval-rmse:10.95632	train-rmse:9.95203
# [405]	eval-rmse:10.95914	train-rmse:9.95131
# [406]	eval-rmse:10.96006	train-rmse:9.95114
# [407]	eval-rmse:10.96028	train-rmse:9.95029
# [408]	eval-rmse:10.96143	train-rmse:9.94961
# [409]	eval-rmse:10.96134	train-rmse:9.94887
# [410]	eval-rmse:10.96110	train-rmse:9.94815
# [411]	eval-rmse:10.96347	train-rmse:9.94744
# [412]	eval-rmse:10.96579	train-rmse:9.94622
# [413]	eval-rmse:10.96533	train-rmse:9.94580
# [414]	eval-rmse:10.96780	train-rmse:9.94434
# [415]	eval-rmse:10.96924	train-rmse:9.94355
# [416]	eval-rmse:10.96934	train-rmse:9.94280
# [417]	eval-rmse:10.96927	train-rmse:9.94270
# [418]	eval-rmse:10.97060	train-rmse:9.94195
# [419]	eval-rmse:10.97054	train-rmse:9.94193
# [420]	eval-rmse:10.97204	train-rmse:9.94106
# [421]	eval-rmse:10.97262	train-rmse:9.94090
# [422]	eval-rmse:10.97396	train-rmse:9.94022
# [423]	eval-rmse:10.97390	train-rmse:9.94020
# [424]	eval-rmse:10.97385	train-rmse:9.94018
# [425]	eval-rmse:10.97389	train-rmse:9.94005
# [426]	eval-rmse:10.97401	train-rmse:9.93976
# [427]	eval-rmse:10.97401	train-rmse:9.93963
# [428]	eval-rmse:10.97446	train-rmse:9.93935
# [429]	eval-rmse:10.97463	train-rmse:9.93841
# [430]	eval-rmse:10.97603	train-rmse:9.93752
# [431]	eval-rmse:10.97848	train-rmse:9.93616
# [432]	eval-rmse:10.97954	train-rmse:9.93447
# [433]	eval-rmse:10.97881	train-rmse:9.93428
# [434]	eval-rmse:10.97838	train-rmse:9.93414
# [435]	eval-rmse:10.97761	train-rmse:9.93391
# [436]	eval-rmse:10.97720	train-rmse:9.93376
# [437]	eval-rmse:10.97683	train-rmse:9.93358
# [438]	eval-rmse:10.97674	train-rmse:9.93356
# [439]	eval-rmse:10.97679	train-rmse:9.93354
# [440]	eval-rmse:10.97844	train-rmse:9.93310
# [441]	eval-rmse:10.97839	train-rmse:9.93308
# [442]	eval-rmse:10.97830	train-rmse:9.93294
# [443]	eval-rmse:10.98096	train-rmse:9.93179
# [444]	eval-rmse:10.98091	train-rmse:9.93177
# [445]	eval-rmse:10.98102	train-rmse:9.93168
# [446]	eval-rmse:10.98405	train-rmse:9.93029
# [447]	eval-rmse:10.98760	train-rmse:9.92848
# [448]	eval-rmse:10.98957	train-rmse:9.92754
# [449]	eval-rmse:10.98854	train-rmse:9.92743
# [450]	eval-rmse:10.98962	train-rmse:9.92671
# [451]	eval-rmse:10.99046	train-rmse:9.92621
# [452]	eval-rmse:10.99123	train-rmse:9.92568
# [453]	eval-rmse:10.99137	train-rmse:9.92515
# [454]	eval-rmse:10.99160	train-rmse:9.92448
# [455]	eval-rmse:10.99391	train-rmse:9.92418
# [456]	eval-rmse:10.99430	train-rmse:9.92392
# [457]	eval-rmse:10.99658	train-rmse:9.92314
# [458]	eval-rmse:10.99619	train-rmse:9.92311
# [459]	eval-rmse:10.99839	train-rmse:9.92249
# [460]	eval-rmse:10.99985	train-rmse:9.92188
# [461]	eval-rmse:10.99730	train-rmse:9.92111
# [462]	eval-rmse:10.99849	train-rmse:9.92063
# [463]	eval-rmse:11.00150	train-rmse:9.91868
# [464]	eval-rmse:11.00262	train-rmse:9.91776
# [465]	eval-rmse:11.00616	train-rmse:9.91628
# [466]	eval-rmse:11.00575	train-rmse:9.91556
# [467]	eval-rmse:11.00804	train-rmse:9.91445
# [468]	eval-rmse:11.00764	train-rmse:9.91399
# [469]	eval-rmse:11.00694	train-rmse:9.91283
# [470]	eval-rmse:11.00863	train-rmse:9.91244
# [471]	eval-rmse:11.01203	train-rmse:9.91096
# [472]	eval-rmse:11.01228	train-rmse:9.91047
# [473]	eval-rmse:11.01360	train-rmse:9.90922
# [474]	eval-rmse:11.01400	train-rmse:9.90844
# [475]	eval-rmse:11.01440	train-rmse:9.90833
# [476]	eval-rmse:11.01596	train-rmse:9.90803
# [477]	eval-rmse:11.01544	train-rmse:9.90783
# [478]	eval-rmse:11.01589	train-rmse:9.90774
# [479]	eval-rmse:11.01626	train-rmse:9.90699
# [480]	eval-rmse:11.01537	train-rmse:9.90660
# [481]	eval-rmse:11.01616	train-rmse:9.90596
# [482]	eval-rmse:11.01304	train-rmse:9.90438
# [483]	eval-rmse:11.01467	train-rmse:9.90327
# [484]	eval-rmse:11.01503	train-rmse:9.90167
# [485]	eval-rmse:11.01624	train-rmse:9.90081
# [486]	eval-rmse:11.01595	train-rmse:9.90079
# [487]	eval-rmse:11.01600	train-rmse:9.90071
# [488]	eval-rmse:11.01854	train-rmse:9.89975
# [489]	eval-rmse:11.01705	train-rmse:9.89910
# [490]	eval-rmse:11.01805	train-rmse:9.89776
# [491]	eval-rmse:11.01902	train-rmse:9.89669
# [492]	eval-rmse:11.01870	train-rmse:9.89667
# [493]	eval-rmse:11.01900	train-rmse:9.89659
# [494]	eval-rmse:11.01878	train-rmse:9.89658
# [495]	eval-rmse:11.01894	train-rmse:9.89650
# [496]	eval-rmse:11.02178	train-rmse:9.89565
# [497]	eval-rmse:11.02145	train-rmse:9.89551
# [498]	eval-rmse:11.02112	train-rmse:9.89536
# [499]	eval-rmse:11.02124	train-rmse:9.89457
# Test Data with Predictions:
#            game_id passer_player_name    sum_epa  mean_temp  is_sunny  \
# 0   2021_06_GB_CHI         Aa.Rodgers   6.792426       62.0         1
# 1  2014_17_CIN_PIT           A.Dalton  -4.906590       37.0         0
# 2   2016_06_DEN_SD           P.Rivers   2.645859       70.0         0
# 3  2022_16_HOU_TEN           M.Willis -17.224499       20.0         1
# 4  2020_18_IND_BUF           P.Rivers  14.806331       34.0         1
#
#    is_cloudy  is_rainy  mean_wind  is_cold  is_windy  predicted_values
# 0          0         0        5.0        0         0          2.154215
# 1          1         0        5.0        0         0          1.752046
# 2          0         0        9.0        0         0         -0.369585
# 3          0         0       10.0        1         0          3.898484
# 4          0         0        6.0        0         0          3.233389
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/core.py:158: UserWarning: [11:18:06] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   warnings.warn(smsg, UserWarning)

# %%
# Combine train_with_predictions and test_with_predictions
predictions = pd.concat([train_with_predictions, test_with_predictions], axis=0)

# Display the combined DataFrame
print("Combined DataFrame (Train + Test):")
print(predictions.head())
# Out:
# Combined DataFrame (Train + Test):
#            game_id passer_player_name    sum_epa  mean_temp  is_sunny  \
# 0   2021_06_GB_CHI         Aa.Rodgers   6.792426       62.0         1
# 1  2014_17_CIN_PIT           A.Dalton  -4.906590       37.0         0
# 2   2016_06_DEN_SD           P.Rivers   2.645859       70.0         0
# 3  2022_16_HOU_TEN           M.Willis -17.224499       20.0         1
# 4  2020_18_IND_BUF           P.Rivers  14.806331       34.0         1
#
#    is_cloudy  is_rainy  mean_wind  is_cold  is_windy  predicted_values
# 0          0         0        5.0        0         0          2.154215
# 1          1         0        5.0        0         0          1.752046
# 2          0         0        9.0        0         0         -0.369585
# 3          0         0       10.0        1         0          3.898484
# 4          0         0        6.0        0         0          3.233389

# %% [markdown]
# ### Testing for error

# %%
# Plot feature importance based on gain, weight, and cover
importance_types = ['weight', 'gain', 'cover']
for imp_type in importance_types:
    xgb.plot_importance(model, importance_type=imp_type, max_num_features=10)
    plt.title(f'Feature Importance ({imp_type.capitalize()})')
    plt.show()

# %%
import matplotlib.pyplot as plt
from xgboost import plot_tree

# Set up the plot size and quality
plt.figure(figsize=(20, 15), dpi=300)  # Increase figure size and DPI for better quality

# Plot the first tree from the XGBoost model
plot_tree(model, num_trees=0)

# Customize font size for better readability
plt.xticks(fontsize=12)  # Adjust x-axis labels font size
plt.yticks(fontsize=12)  # Adjust y-axis labels font size

# Display the plot
plt.show()

# %% [markdown]
# K-fold cross validation:

# %%
dtrain = xgb.DMatrix(data=train_features, label=train_label)
params = {
    'max_depth': 3,
    'eta': 0.14,
    'objective': 'reg:squarederror',
    'eval_metric': 'rmse'
}

cv_results = xgb.cv(params, dtrain, num_boost_round=500, nfold=5, early_stopping_rounds=10, seed=42)
print(cv_results)

plt.plot(cv_results['train-rmse-mean'], label='Train RMSE')
plt.plot(cv_results['test-rmse-mean'], label='Test RMSE')
plt.xlabel('Boosting Round')
plt.ylabel('RMSE')
plt.legend()
plt.title('Cross-Validation RMSE')
plt.show()
# Out:
#    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0        10.609732        0.023335       10.630723       0.091860
# 1        10.590544        0.024759       10.626562       0.095714
# 2        10.576884        0.025091       10.622937       0.093339
# 3        10.563027        0.025346       10.622774       0.096496
# 4        10.552044        0.025368       10.618095       0.097012
# 5        10.539317        0.026871       10.617913       0.097047
# 6        10.529580        0.026604       10.617891       0.097674
# 7        10.521104        0.026987       10.616816       0.098809

# %% [markdown]
# Residual analysis

# %%
residuals = test_with_predictions['predicted_values'] - test_with_predictions['sum_epa']
plt.hist(residuals, bins=30)
plt.xlabel('Residual')
plt.ylabel('Frequency')
plt.title('Residual Distribution')
plt.show()

# %% [markdown]
# Bias analysis

# %%
mean_residual = residuals.mean()
print(f"Mean Residual (Bias Estimate): {mean_residual}")
# Out:
# Mean Residual (Bias Estimate): 0.3393363952636719

# %% [markdown]
# Overall model evaluation (MAE, MSE, RMSE)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

mae = mean_absolute_error(test_with_predictions['sum_epa'], test_with_predictions['predicted_values'])
mse = mean_squared_error(test_with_predictions['sum_epa'], test_with_predictions['predicted_values'])
rmse = mean_squared_error(test_with_predictions['sum_epa'], test_with_predictions['predicted_values'], squared=False)

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
# Out:
# MAE: 8.702155113220215
# MSE: 121.46764373779297
# RMSE: 11.021236419677734

# %% [markdown]
# Learning curve analysis:

# %%
train_rmse = cv_results['train-rmse-mean']
test_rmse = cv_results['test-rmse-mean']

plt.plot(train_rmse, label='Training RMSE')
plt.plot(test_rmse, label='Validation RMSE')
plt.xlabel('Boosting Round')
plt.ylabel('RMSE')
plt.legend()
plt.title('Learning Curve')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming sum_epa and predicted_values are available as arrays or pandas Series
# For example:
# sum_epa = df['sum_epa']
# predicted_values = model.predict(X_test)

plt.figure(figsize=(10, 6))  # Adjust figure size for better clarity

# Scatterplot with regression line for better comparison
sns.regplot(x=predictions["sum_epa"], y=predictions["predicted_values"], scatter_kws={'color': 'blue', 'alpha': 0.5}, line_kws={'color': 'red', 'linestyle': '--'})

# Adding labels and title
plt.xlabel('Actual Values', fontsize=12)
plt.ylabel('Predicted Values', fontsize=12)
plt.title('Comparison of Actual vs Predicted EPA per game in Quarterbacks', fontsize=14)

# Show the plot
plt.grid(True)
plt.show()

# %% [markdown]
# ### Applications

# %% [markdown]
# In our applications section, we are going to try to predict a couple things. First, we will use the residuals to create a weather-adjusted "epa over expected" metric. Then, we will try to see the best players in each circumstance. We will then compare a couple players and explain what the numbers mean.

# %% [markdown]
# Here are the best players in terms of weather-adjusted EPA Over Expected

# %%
predictions["epaoe"] = predictions["sum_epa"] - predictions["predicted_values"]
predictions["passer_player_name"] = np.where(predictions["passer_player_name"] == "Aa.Rodgers", "A.Rodgers", predictions["passer_player_name"])
# Multiple aggregation functions
# Group by 'passer_player_name' and calculate the mean of 'epaoe'
players = predictions.groupby("passer_player_name").agg(
    mean_epaoe =('epaoe', 'mean'), actual_epa = ("sum_epa", "mean"), count=('passer_player_name', 'size') 

).reset_index()

# Sort by 'mean_epaoe' in descending order
players = players.sort_values(by="mean_epaoe", ascending=False)

# Display the resulting DataFrame
players = players[players["count"] > 10]
print(players)
# Out:
#     passer_player_name  mean_epaoe  actual_epa  count
# 133          P.Mahomes    8.054402    8.600468    109
# 164             T.Romo    7.206429    8.898573     14
# 20             B.Purdy    6.759869    8.199790     27
# 155            T.Brady    5.472613    6.356368    151
# 7            A.Rodgers    4.783755    5.816825    125
# 47             D.Brees    4.173600    5.921350     92
# 88              J.Love    3.733722    3.831021     18
# 81         J.Garoppolo    3.693906    4.653359     63
# 56          D.Prescott    3.162725    3.476615     69
# 21    B.Roethlisberger    3.146628    4.238270    112
# 135           P.Rivers    3.123842    4.377399    107
# 167       T.Tagovailoa    2.975553    3.434438     51
# 70             J.Allen    2.905284    3.289250     93
# 41            C.Stroud    2.689166    3.678997     17
# 3               A.Luck    2.682509    3.808017     55
# 36            C.Palmer    2.590477    4.459265     19
# 123         M.Stafford    2.574130    3.815424     83
# 73            J.Burrow    2.356926    3.568355     56
# 134          P.Manning    1.926217    1.750528     28
# 129          N.Mullens    1.854301    3.191702     22
# 99           K.Cousins    1.790163    2.618120    116
# 107          L.Jackson    1.677630    2.738711     77
# 60            D.Watson    1.604750    2.771478     63
# 84           J.Herbert    1.584794    3.211238     62
# 82              J.Goff    1.489625    2.263984     87
# 120             M.Ryan    1.280458    2.864489     92
# 8              A.Smith    1.061489    1.526836     77
# 85             J.Hurts    1.038861    1.727191     53
# 138      R.Fitzpatrick    0.794029    1.726374     66
# 144           R.Wilson    0.668883    1.791534    149
# 143        R.Tannehill    0.449541    1.559103    118
# 43             C.Wentz    0.412907    0.522961     85
# 48              D.Carr    0.356328    0.964072    149
# 94           J.Winston    0.044848    1.387223     72
# 156      T.Bridgewater    0.013624    0.773038     58
# 1             A.Dalton   -0.070387    0.319263    113
# 16          B.Mayfield   -0.104098    0.722875     92
# 168           T.Taylor   -0.162722   -0.071309     57
# 124         M.Trubisky   -0.445236   -0.611503     50
# 116          M.Mariota   -0.738530    0.069841     75
# 118            M.Moore   -0.844332    0.240235     11
# 68             G.Smith   -0.979683   -0.279856     47
# 162         T.Lawrence   -1.004248   -0.399662     51
# 62           E.Manning   -1.071589   -0.433885     73
# 67        G.Minshew II   -1.124591    0.108330     13
# 35            C.Newton   -1.129187   -0.344152     95
# 119          M.Rudolph   -1.184242   -1.281987     16
# 145         S.Bradford   -1.399102   -0.839238     21
# 103           K.Murray   -1.551568    0.247185     47
# 66           G.Minshew   -1.638876   -0.593497     25
# 79            J.Flacco   -1.770974   -0.926029     89
# 105          K.Pickett   -1.848592   -2.164035     24
# 158         T.Heinicke   -1.866414   -1.473287     31
# 54              D.Lock   -1.942105   -1.177513     24
# 57            D.Ridder   -1.950359   -1.822516     16
# 115            M.Jones   -2.144487   -1.421499     39
# 31        C.Kaepernick   -2.237932   -1.224730     27
# 91            J.McCown   -2.283235   -1.716017     37
# 71          J.Brissett   -2.464557   -1.568104     50
# 160          T.Huntley   -2.677719   -3.638073     14
# 14             B.Hoyer   -2.744053   -1.785359     39
# 33           C.Kessler   -2.822654   -2.034290     12
# 11           B.Bortles   -2.878869   -2.035127     72
# 5          A.O'Connell   -2.986099   -2.032755     11
# 32            C.Keenum   -3.252427   -2.631727     47
# 52             D.Jones   -3.292621   -3.064169     55
# 34             C.McCoy   -3.379819   -1.699363     13
# 98             K.Allen   -3.626305   -3.938694     17
# 75            J.Cutler   -3.705483   -2.686853     40
# 17          B.Osweiler   -3.893970   -3.197069     33
# 128            N.Foles   -4.024352   -3.564250     36
# 146          S.Darnold   -4.025822   -3.634632     54
# 78            J.Fields   -4.302154   -4.567199     37
# 166          T.Siemian   -4.617834   -4.221354     36
# 76             J.Dobbs   -5.113708   -6.933323     11
# 121          M.Sanchez   -5.133376   -4.016786     12
# 55             D.Mills   -5.198629   -4.059758     27
# 77           J.Driskel   -5.413585   -5.347554     11
# 25             B.Zappe   -5.699745   -6.085890     11
# 50           D.Haskins   -5.741513   -5.688486     13
# 136           P.Walker   -6.068210   -6.322597     14
# 174           Z.Wilson   -6.126071   -6.888091     32
# 26          C.Beathard   -6.278952   -4.487581     17
# 13           B.Gabbert   -6.626618   -5.935542     22
# 113          M.Glennon   -6.664556   -6.486051     20
# 149           S.Howell   -7.404912   -6.740172     17
# 173     Z.Mettenberger   -8.156440   -8.026267     11
# 139          R.Griffin   -8.689645   -8.887733     11
# 53             D.Kizer   -9.756145   -9.685771     15
# 24             B.Young  -10.021583  -11.103192     15
# 92             J.Rosen  -14.350644  -12.760587     12

# %% [markdown]
# ### Best players in rain:

# %%
rainy_games = predictions[predictions["is_rainy"] == 1]
players_rain = rainy_games.groupby("passer_player_name").agg(
    epaoe_rain =('epaoe', 'mean'), epa_rain = ("sum_epa", "mean"), count_rain =('passer_player_name', 'size') 

).reset_index()

players_rain = players_rain.sort_values(by="epaoe_rain", ascending=False)

players_rain = players_rain[players_rain["count_rain"] > 4]
print(players_rain)
# Out:
#    passer_player_name  epaoe_rain   epa_rain  count_rain
# 24            D.Brees   11.055251  13.282163           5
# 83            T.Brady    7.418390   6.041208          12
# 78        R.Tannehill    4.755206   2.791818           5
# 29         D.Prescott    3.058683  -0.761609           5
# 12   B.Roethlisberger    2.967816   0.621943           8
# 2           A.Rodgers    2.220145   2.288956           8
# 79           R.Wilson    2.208732  -0.059037          12
# 36            J.Allen    1.774648  -0.540475          12
# 19           C.Newton    1.390352   1.208961           6
# 3             A.Smith    1.128869   1.614912           7
# 57          L.Jackson    0.641758  -1.797334          10
# 23            C.Wentz    0.164145  -2.199650          10
# 25             D.Carr   -0.066121  -0.672239           5
# 0            A.Dalton   -0.327387   0.917141           6
# 35            G.Smith   -1.163242  -1.692552           5
# 17           C.Keenum   -1.286403  -4.422141           5
# 33          E.Manning   -1.473609  -3.028135           7
# 92           T.Taylor   -2.775105  -5.429375           6
# 1              A.Luck   -2.786026  -1.822233           6
# 9          B.Mayfield   -3.635590  -4.862289           6
# 48            J.Hurts   -4.086751  -6.018561           5
# 43           J.Flacco   -4.134768  -3.513630           6
# 62          M.Mariota   -5.464084  -5.711016           8
# 5           B.Bortles   -6.478600  -5.926975          12
# 27            D.Jones   -6.723175  -8.659881           6

# %% [markdown]
# ### Best players in wind:

# %%
windy_games = predictions[predictions["mean_wind"] >14]
players_wind = windy_games.groupby("passer_player_name").agg(
    epaoe_wind =('epaoe', 'mean'), epa_wind = ("sum_epa", "mean"), count_wind =('passer_player_name', 'size') 

).reset_index()

players_wind = players_wind.sort_values(by="epaoe_wind", ascending=False)

players_wind = players_wind[players_wind["count_wind"] > 4]
print(players_wind)
# Out:
#     passer_player_name  epaoe_wind   epa_wind  count_wind
# 88           P.Mahomes   10.328201   8.877411          15
# 31             D.Brees    9.557712  14.395182          10
# 56              J.Goff    6.855964   5.984429           7
# 100            T.Brady    6.477791   7.018212          13
# 109       T.Tagovailoa    6.349900   3.194122           7
# 49            J.Burrow    5.721422   4.772493           6
# 72           L.Jackson    5.297998   4.003143           7
# 92       R.Fitzpatrick    4.553936   2.606496          13
# 2               A.Luck    3.650284   4.480347           5
# 47             J.Allen    3.581002   2.132090          15
# 4            A.Rodgers    3.157206   4.210443          13
# 90            P.Rivers    3.017158   2.258314           9
# 15    B.Roethlisberger    2.981478   2.535142          13
# 65           J.Winston    2.956028   2.669636           9
# 68           K.Cousins    2.499831   3.210447          12
# 38          D.Prescott    1.843250  -0.620970           5
# 28             C.Wentz    1.779809  -1.178876          12
# 0             A.Dalton    1.754621  -0.236541          10
# 101      T.Bridgewater    1.043658   3.046504          10
# 94         R.Tannehill    0.330350   0.434177          10
# 110           T.Taylor    0.047486   0.089350           6
# 10             B.Hoyer    0.041479   2.816674           6
# 34             D.Jones   -0.030562  -0.329329           6
# 83          M.Trubisky   -0.446120  -2.436093           5
# 32              D.Carr   -0.562781  -2.121690          24
# 25            C.Newton   -1.372524  -5.361501           7
# 58             J.Hurts   -1.499324  -0.563406           6
# 42           E.Manning   -1.525026  -6.733924           5
# 12          B.Mayfield   -1.561100  -2.209736          13
# 46             G.Smith   -1.579890  -3.251017           6
# 5              A.Smith   -1.905553  -1.206314           9
# 62            J.McCown   -2.265319  -2.748270           9
# 7            B.Bortles   -2.518877   0.122223           9
# 50            J.Cutler   -2.722420  -0.276548           5
# 95            R.Wilson   -2.782023  -3.357599          10
# 77             M.Moore   -2.917139  -1.534387           5
# 48          J.Brissett   -3.589293  -3.445906           6
# 52            J.Fields   -3.739631  -6.264943           6
# 75             M.Jones   -3.871743  -3.602601           5
# 89           P.Manning   -4.396173  -6.310788           5
# 53            J.Flacco   -5.802567  -5.056772           9
# 85             N.Foles   -8.828526  -9.594169           6
# 97           S.Darnold  -10.469125 -12.685577           7

# %% [markdown]
# ### Best players in cold

# %%
cold_games = predictions[predictions["mean_temp"] >= 32]
players_cold = cold_games.groupby("passer_player_name").agg(
    epaoe_cold =('epaoe', 'mean'), epa_cold = ("sum_epa", "mean"), count_cold =('passer_player_name', 'size') 

).reset_index()

players_cold = players_cold.sort_values(by="epaoe_cold", ascending=False)

players_cold = players_cold[players_cold["count_cold"] > 4]
print(players_cold)
# Out:
#     passer_player_name  epaoe_cold   epa_cold  count_cold
# 130          P.Mahomes    7.975887   8.794204          95
# 161             T.Romo    7.874405   9.295938          13
# 19             B.Purdy    6.759869   8.199790          27
# 152            T.Brady    5.273582   6.174415         138
# 7            A.Rodgers    4.479030   5.602281         105
# 46             D.Brees    4.173600   5.921350          92
# 80         J.Garoppolo    3.761171   4.849505          62
# 20    B.Roethlisberger    3.277226   4.484264         105
# 132           P.Rivers    3.264058   4.441026         105
# 164       T.Tagovailoa    3.133378   3.899319          49
# 71          J.Browning    3.125417   3.074888           8
# 69             J.Allen    2.989958   3.346123          82
# 40            C.Stroud    2.983196   4.178585          16
# 55          D.Prescott    2.722463   2.959667          66
# 3               A.Luck    2.635459   3.748270          53
# 35            C.Palmer    2.590477   4.459265          19
# 120         M.Stafford    2.523150   3.822865          79
# 86              J.Love    2.410855   2.472054          16
# 72            J.Burrow    2.385759   3.605353          54
# 131          P.Manning    2.082040   1.773262          27
# 126          N.Mullens    2.008579   3.543531          21
# 96           K.Cousins    1.952108   2.867907         108
# 59            D.Watson    1.678881   3.038645          61
# 104          L.Jackson    1.625899   2.670979          75
# 81              J.Goff    1.604841   2.444834          83
# 84           J.Johnson    1.566377   2.368164           7
# 82           J.Herbert    1.557882   3.312312          61
# 117             M.Ryan    1.483482   3.092919          88
# 83             J.Hurts    1.215780   2.093756          51
# 8              A.Smith    1.144223   1.696319          72
# 108          M.Barkley    1.129006   1.016682           8
# 135      R.Fitzpatrick    0.794029   1.726374          66
# 141           R.Wilson    0.730801   2.036170         142
# 47              D.Carr    0.536305   1.224418         144
# 42             C.Wentz    0.427062   0.593505          84
# 140        R.Tannehill    0.413378   1.494940         115
# 1             A.Dalton    0.143690   0.886872         105
# 15          B.Mayfield    0.046758   0.974932          89
# 92           J.Winston    0.044848   1.387223          72
# 153      T.Bridgewater   -0.119797   1.345478          52
# 115            M.Moore   -0.542373   0.536232          10
# 165           T.Taylor   -0.608051  -0.374689          53
# 116          M.Rudolph   -0.636084  -0.944912          15
# 121         M.Trubisky   -0.655377  -0.455748          46
# 67             G.Smith   -0.767722   0.109086          46
# 61           E.Manning   -0.789013   0.162830          70
# 113          M.Mariota   -0.939914   0.211044          72
# 34            C.Newton   -0.990229  -0.069131          92
# 159         T.Lawrence   -1.004248  -0.399662          51
# 66        G.Minshew II   -1.124591   0.108330          13
# 139          R.Mallett   -1.199166  -1.532875           8
# 111       M.Hasselbeck   -1.352498   0.309715           8
# 142         S.Bradford   -1.399102  -0.839238          21
# 169            W.Levis   -1.468844  -0.398368           8
# 100           K.Murray   -1.551568   0.247185          47
# 65           G.Minshew   -1.561604  -0.716294          24
# 53              D.Lock   -1.564281  -0.139523          21
# 78            J.Flacco   -1.650908  -0.873825          85
# 123            M.White   -1.712206  -0.983288           7
# 155         T.Heinicke   -1.866414  -1.473287          31
# 4           A.McCarron   -1.994712  -2.064669           5
# 102          K.Pickett   -2.079440  -2.317753          23
# 56            D.Ridder   -2.109284  -1.835861          15
# 50            D.Hodges   -2.154187  -3.048499           5
# 112            M.Jones   -2.227497  -1.630215          36
# 30        C.Kaepernick   -2.237932  -1.224730          27
# 89            J.McCown   -2.283235  -1.716017          37
# 43        C.Whitehurst   -2.474422  -0.685343          10
# 70          J.Brissett   -2.487792  -1.558992          48
# 14           B.Hundley   -2.508247  -1.444357           6
# 156             T.Hill   -2.560313  -2.752144           8
# 13             B.Hoyer   -2.744053  -1.785359          39
# 91           J.Stidham   -2.811455  -2.171956           8
# 101            K.Orton   -2.813480  -1.617438          10
# 32           C.Kessler   -2.822654  -2.034290          12
# 10           B.Bortles   -2.844922  -2.027628          70
# 5          A.O'Connell   -2.986099  -2.032755          11
# 157          T.Huntley   -2.988794  -3.864878          13
# 51             D.Jones   -3.367663  -3.061120          54
# 33             C.McCoy   -3.379819  -1.699363          13
# 125            N.Foles   -3.520473  -2.654108          32
# 31            C.Keenum   -3.601245  -2.675498          45
# 95             K.Allen   -3.626305  -3.938694          17
# 74            J.Cutler   -3.777894  -2.788433          35
# 162           T.Savage   -4.104032  -3.693737           8
# 163          T.Siemian   -4.354365  -3.920405          34
# 143          S.Darnold   -4.439923  -4.167576          52
# 75             J.Dobbs   -4.489744  -5.247602          10
# 85            J.Locker   -4.555718  -4.636120           7
# 44          D.Anderson   -4.698735  -5.703229           5
# 77            J.Fields   -4.834263  -4.446159          34
# 16          B.Osweiler   -4.847969  -3.985775          28
# 88           J.Manziel   -4.959788  -4.320904           8
# 54             D.Mills   -5.120493  -4.087761          26
# 154           T.DeVito   -5.199881  -4.836501           6
# 118          M.Sanchez   -5.365151  -4.352379          11
# 76           J.Driskel   -5.413585  -5.347554          11
# 9              B.Allen   -5.562200  -5.645628           8
# 49           D.Haskins   -5.741513  -5.688486          13
# 110          M.Glennon   -5.746850  -4.955589          19
# 57           D.Stanton   -5.758147  -4.969194           9
# 150           T.Bagent   -5.892307  -6.454490           5
# 151            T.Boyle   -5.920084  -6.645413           6
# 133           P.Walker   -6.068210  -6.322597          14
# 171           Z.Wilson   -6.126071  -6.888091          32
# 62            E.Manuel   -6.195814  -5.627660           9
# 25          C.Beathard   -6.278952  -4.487581          17
# 2              A.Davis   -6.584682  -5.571733           7
# 12           B.Gabbert   -6.626618  -5.935542          22
# 24             B.Zappe   -6.672183  -7.012502          10
# 21            B.Rypien   -6.836828  -6.699268           6
# 28             C.Henne   -6.918832  -5.326789           5
# 146           S.Howell   -7.404912  -6.740172          17
# 166            T.Yates   -7.493201  -7.124213           5
# 109           M.Cassel   -7.998151  -7.492776          10
# 18             B.Petty   -8.350261  -9.074939           6
# 63             E.Stick   -8.581421  -6.802397           5
# 122             M.Vick   -8.625983  -8.163397           6
# 170     Z.Mettenberger   -8.674358  -8.811252           9
# 73           J.Clausen   -9.361535  -8.023732           5
# 136          R.Griffin   -9.472411  -9.535889           9
# 23             B.Young  -10.021583 -11.103192          15
# 52             D.Kizer  -10.897011 -10.627460          11
# 127         N.Peterman  -12.346725 -12.266029           7
# 90             J.Rosen  -14.350644 -12.760587          12
# 134           R.Finley  -14.613821 -14.943323           5

# %% [markdown]
# ### Final visualizations

# %%
players_agg = players.merge(players_rain, on="passer_player_name", how="left") \
                     .merge(players_wind, on="passer_player_name", how="left") \
                     .merge(players_cold, on="passer_player_name", how="left") \
                     .dropna()
players_agg = players_agg.head(10)

# %%
df_melted = players_agg.melt(
    id_vars="passer_player_name", 
    value_vars=["mean_epaoe", "epaoe_rain", "epaoe_wind", "epaoe_cold"],
    var_name="Condition", 
    value_name="EPAOE"
)

# Plot the fluctuations
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_melted, x="Condition", y="EPAOE", hue="passer_player_name", marker="o")
plt.xticks(rotation=45)
plt.xlabel("Condition")
plt.ylabel("EPAOE")
plt.title("Fluctuations of EPAOE Across Conditions for Each Player")
plt.legend(title="Player Name", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
